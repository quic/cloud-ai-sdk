# %% [markdown]
# Copyright (c) 2023 Qualcomm Innovation Center, Inc. All rights reserved. <br>
# SPDX-License-Identifier: BSD-3-Clause-Clear

# %% [markdown]
# **Takeaways:** Users will learn how to tune the BERT base neural network model for best throughput and latency
#
# **Before you start:**
# - There are some commands (folder locations etc) that will need to be updated in this notebook based on the platform and installation location. Some commands might need sudo prefix to run properly.
# - The terms 'model' and 'network' are used interchangeably in this notebook.
# - The terms 'NSP' and 'AI compute core" are used interchangeably in this notebook.
#
# **Last Verified Qualcomm Cloud AI Platform SDK and Apps SDK Version:** Platform SDK 1.10.0.193 and Apps SDK 1.10.0.193

# %% [markdown]
# # <span style='color:Blue'> Performance Tuning on Cloud AI </span>
#
# ##  Pre-requisite reading
# New users on Cloud AI platforms are expected to go over the Cloud AI SoC architecture and the key compile/runtime parameters that determine performance. This is discussed in the Tune Performance section in the Inference workflow documentation.
#
#
# ## Introduction
# This notebook is for beginners and will take the user through the workflow to achieve best throughput and latency on Cloud AI platforms for the 'bert-base-cased' model from HuggingFace.
#
# Here is the workflow that will be demonstated in this notebook.
#
# 1. **Install required packages**: Begin by installing all the required packages
# 2. **Import the model**: Download the bert-base-cased model from HuggingFace in ONNX.
# 2. **Device Health Check**: Query the device health using qaic-util tool.
# 2. **Identify best throughput configuration**: Go over the Model Configurator tool to identify best throughput
# 3. **Identity least latency configuration**: Go over the key parameters to tweak for least latency

# %% [markdown]
# # <span style='color:Blue'> 1. Install required packages </span>
#
# We will install the required Python packages

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: onnx==1.12.0 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from -r requirements.txt (line 1)) (1.12.0)
# Requirement already satisfied: optimum in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from -r requirements.txt (line 2)) (1.9.0)
# Collecting numpy==1.23.4 (from -r requirements.txt (line 3))
#   Using cached numpy-1.23.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
# Requirement already satisfied: onnxruntime in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from -r requirements.txt (line 4)) (1.12.1)
# Requirement already satisfied: torch===1.11.0 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from -r requirements.txt (line 5)) (1.11.0)
# Requirement already satisfied: pillow==8.3.2 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from -r requirements.txt (line 6)) (8.3.2)
# Requirement already satisfied: opencv-python in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from -r requirements.txt (line 7)) (4.5.2.52)
# Requirement already satisfied: paramiko in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from -r requirements.txt (line 8)) (2.10.4)
# Requirement already satisfied: protobuf<=3.20.1,>=3.12.2 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from onnx==1.12.0->-r requirements.txt (line 1)) (3.20.1)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from onnx==1.12.0->-r requirements.txt (line 1)) (4.6.0)
# Requirement already satisfied: coloredlogs in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from optimum->-r requirements.txt (line 2)) (15.0.1)
# Requirement already satisfied: sympy in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from optimum->-r requirements.txt (line 2)) (1.10.1)
# Requirement already satisfied: transformers[sentencepiece]>=4.26.0 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from optimum->-r requirements.txt (line 2)) (4.30.2)
# Requirement already satisfied: packaging in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from optimum->-r requirements.txt (line 2)) (23.1)
# Requirement already satisfied: huggingface-hub>=0.8.0 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from optimum->-r requirements.txt (line 2)) (0.14.1)
# Requirement already satisfied: datasets in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from optimum->-r requirements.txt (line 2)) (2.7.0)
# Requirement already satisfied: flatbuffers in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from onnxruntime->-r requirements.txt (line 4)) (1.12)
# Requirement already satisfied: bcrypt>=3.1.3 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from paramiko->-r requirements.txt (line 8)) (4.0.1)
# Requirement already satisfied: cryptography>=2.5 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from paramiko->-r requirements.txt (line 8)) (40.0.2)
# Requirement already satisfied: pynacl>=1.0.1 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from paramiko->-r requirements.txt (line 8)) (1.5.0)
# Requirement already satisfied: six in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from paramiko->-r requirements.txt (line 8)) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from cryptography>=2.5->paramiko->-r requirements.txt (line 8)) (1.15.1)
# Requirement already satisfied: filelock in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from huggingface-hub>=0.8.0->optimum->-r requirements.txt (line 2)) (3.12.0)
# Requirement already satisfied: fsspec in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from huggingface-hub>=0.8.0->optimum->-r requirements.txt (line 2)) (2023.5.0)
# Requirement already satisfied: requests in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from huggingface-hub>=0.8.0->optimum->-r requirements.txt (line 2)) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from huggingface-hub>=0.8.0->optimum->-r requirements.txt (line 2)) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from huggingface-hub>=0.8.0->optimum->-r requirements.txt (line 2)) (5.4.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from transformers[sentencepiece]>=4.26.0->optimum->-r requirements.txt (line 2)) (2023.5.5)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from transformers[sentencepiece]>=4.26.0->optimum->-r requirements.txt (line 2)) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from transformers[sentencepiece]>=4.26.0->optimum->-r requirements.txt (line 2)) (0.3.1)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from transformers[sentencepiece]>=4.26.0->optimum->-r requirements.txt (line 2)) (0.1.99)
# Requirement already satisfied: humanfriendly>=9.1 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from coloredlogs->optimum->-r requirements.txt (line 2)) (10.0)
# Requirement already satisfied: pyarrow>=6.0.0 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from datasets->optimum->-r requirements.txt (line 2)) (12.0.0)
# Requirement already satisfied: dill<0.3.7 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from datasets->optimum->-r requirements.txt (line 2)) (0.3.6)
# Requirement already satisfied: pandas in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from datasets->optimum->-r requirements.txt (line 2)) (1.4.3)
# Requirement already satisfied: xxhash in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from datasets->optimum->-r requirements.txt (line 2)) (3.2.0)
# Requirement already satisfied: multiprocess in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from datasets->optimum->-r requirements.txt (line 2)) (0.70.14)
# Requirement already satisfied: aiohttp in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from datasets->optimum->-r requirements.txt (line 2)) (3.8.4)
# Requirement already satisfied: responses<0.19 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from datasets->optimum->-r requirements.txt (line 2)) (0.18.0)
# Requirement already satisfied: mpmath>=0.19 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from sympy->optimum->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: pycparser in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from cffi>=1.12->cryptography>=2.5->paramiko->-r requirements.txt (line 8)) (2.21)
# Requirement already satisfied: attrs>=17.3.0 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from aiohttp->datasets->optimum->-r requirements.txt (line 2)) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from aiohttp->datasets->optimum->-r requirements.txt (line 2)) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from aiohttp->datasets->optimum->-r requirements.txt (line 2)) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from aiohttp->datasets->optimum->-r requirements.txt (line 2)) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from aiohttp->datasets->optimum->-r requirements.txt (line 2)) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from aiohttp->datasets->optimum->-r requirements.txt (line 2)) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from aiohttp->datasets->optimum->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from requests->huggingface-hub>=0.8.0->optimum->-r requirements.txt (line 2)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from requests->huggingface-hub>=0.8.0->optimum->-r requirements.txt (line 2)) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from requests->huggingface-hub>=0.8.0->optimum->-r requirements.txt (line 2)) (2023.5.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from pandas->datasets->optimum->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from pandas->datasets->optimum->-r requirements.txt (line 2)) (2023.3)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.0
#     Uninstalling numpy-1.23.0:
# ERROR: Could not install packages due to an OSError: [Errno 13] Permission denied: '/opt/qti-aic/dev/python/qaic-env/bin/f2py'
# Check the permissions.
#
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# # <span style='color:Blue'>2. Download the model </span>
#
# Download the pretrained bert-base-cased model using optimum-cli.

# %%
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"
# !optimum-cli export onnx --model bert-base-cased --cache_dir model_files/cased --opset 11 --task question-answering bert_base_cased_onnx/
# Out:
# 2023-07-19 11:51:19.157563: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-07-19 11:51:19.157609: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Framework not specified. Using pt to export to ONNX.
# Downloading (…)lve/main/config.json: 100%|██████| 570/570 [00:00<00:00, 159kB/s]
# Downloading model.safetensors: 100%|██████████| 436M/436M [00:04<00:00, 100MB/s]
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForQuestionAnswering: ['cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Using framework PyTorch: 1.11.0+cu102
# Overriding 1 configuration item(s)
# 	- use_cache -> False
# Post-processing the exported models...
# Validating models in subprocesses...
# 2023-07-19 11:51:35.520825: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-07-19 11:51:35.520870: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Validating ONNX model bert_base_cased_onnx/model.onnx...
# 	-[✓] ONNX model output names match reference model (end_logits, start_logits)
# 	- Validating ONNX Model output "start_logits":
# 		-[✓] (2, 16) matches (2, 16)
# 		-[✓] all values close (atol: 0.0001)
# 	- Validating ONNX Model output "end_logits":
# 		-[✓] (2, 16) matches (2, 16)
# 		-[✓] all values close (atol: 0.0001)
# The ONNX export succeeded and the exported model was saved at: bert_base_cased_onnx

# %%
import numpy as np
import onnx
from onnx import numpy_helper
        
def fix_onnx_fp16(
    gen_models_path: str,
    model_base_name: str,
) -> str:
    finfo = np.finfo(np.float16)
    fp16_max = finfo.max
    fp16_min = finfo.min

    model = onnx.load(f"{gen_models_path}/{model_base_name}.onnx")
    fp16_fix = False
    for tensor in onnx.external_data_helper._get_all_tensors(model):
        nptensor = numpy_helper.to_array(tensor, gen_models_path)
        if nptensor.dtype == np.float32 and (
            np.any(nptensor > fp16_max) or np.any(nptensor < fp16_min)
        ):
            print(f'tensor value : {nptensor} above {fp16_max} or below {fp16_min}')
            nptensor = np.clip(nptensor, fp16_min, fp16_max)
            new_tensor = numpy_helper.from_array(nptensor, tensor.name)
            tensor.CopyFrom(new_tensor)
            fp16_fix = True
            
    if fp16_fix:
        # Save FP16 model
        print("Found constants out of FP16 range, clipped to FP16 range")
        model_base_name += "_fix_outofrange_fp16"
        onnx.save(model, f=f"{gen_models_path}/{model_base_name}.onnx")
        print(f"Saving modified onnx file at {gen_models_path}/{model_base_name}.onnx")
    return model_base_name

fp16_model_name = fix_onnx_fp16(gen_models_path="bert_base_cased_onnx", model_base_name="model")
# Out:
# tensor value : -3.4028234663852886e+38 above 65504.0 or below -65504.0
# Found constants out of FP16 range, clipped to FP16 range
# Saving modified onnx file at bert_base_cased_onnx/model_fix_outofrange_fp16.onnx

# %% [markdown]
# # <span style='color:Blue'> 3. Check device health </span>
#
# 'qaic-util' tool can be used to query the health of all the Cloud AI cards in the server.
#
# "Status: Ready" indicates that the health of the cards is good.
# "Status: Error" indicates that the cards are not in good health and a system administrator needs to be contacted to rectify the issue.

# %%
# !/opt/qti-aic/tools/qaic-util -q | grep "Status"
# Out:
# 	Status:Ready
# 	Status:Error
# 	Status:Ready
# 	Status:Ready

# %% [markdown]
# # <span style='color:Blue'> 4. Identify the best throughput configuration </span>
#
# Model Configurator is a python script that is used to find the optimal configuration of batch size, cores etc for a given model for the throughput (Inf/s). The input to model configurator is the model and a search space that the tool iterates over.
#
# 1. Use the optimal config (model configurator output) as an indicator of the best compile flags.
# 2. Compile with qaic-exec and run with qaic-runner using optimal config from step 1 to validate the performance.
#
# Key compile optimization flags are
# - **aic-num-cores** : # of AI compute cores (aka NSP) used to compile the model
# - **bs** : batch size
# - **mos** : Maximum output splitting, denotes the no of AI compute cores across which an output channel (and associated weights) is split.
# - **ols** : Overlap splitting, enabled output splitting to improve core level parallelism, eg tensor and vector unit
#
# Key runtime optimization flags are
# - **instance/activations** : No of instances of the compiled binary that can be run based on the # of AI compute cores on the card
# - **set-size** : denotes the number of inferences per instance that can be queued up on the host. Hides host side overhead by pipelining inferences

# %% [markdown]
# ## Config Optimizer
# The optimized search is run on one or more searchable parameters (aic-num-cores, instances, batch-size etc). The search space is provided through a json configuration file.
# This table captures the key elements of the configuration file.
#
# | Key | Type | Description | Recommended value|
# | :- |:- | :- | :-|
# |"max_func_eval"|Integer|Maximun number of evaluations to do for each initial point. This number can be increased if successful convergence is not achieved|200|
# |"Objective"|String| Search objective. Options are "maximize_inf_rate" | |
# |“params”|Json Object|Provide the search range for each of the parameters - cores, mos, ols, etc. through min, max values| See table below |
# “initial_values”|List of Json Objects|List of initial values for the search parameters. A fresh search is initiated from each of these points and the results returned. Initial Values must be picked from within the search range defined in “params”|	Provide multiple initial values as shown in the example json|
# |“static_params”|Json Object|Optional static values to be used for searchable parameters which have been excluded from the search space| |
#
#
# ### Parameter Range
#
#
# | Parameter|	Recommended Search Range|	Valid Range |	Comments|
# | :- | :- | :- | :-|
# |cores|	1-Number of NSP on device|	1-Number of NSP on device||
# |mos	|1-Number of NSP on device|	1-Number of NSP on device||
# |ols	|1-8|	Integers>0|
# |batch-size (bs)|	1-16|	Integers>0|	Min, max values must be power of 2. The max value would depend on the model|
# |instances|	1-Number of NSP on device|	1-Number of NSP on device|

# %%
#Lets assume the max Number of NSP on the device is 14. 
# !cat bert_base_dopt.json
# Out:
# {
#   "max_func_eval": 200,
#   "objective": "maximize_inf_rate",
#   "params": {
#     "cores": {
#       "min": 1,
#       "max": 14
#     },
#     "mos": {
#       "min": 1,
#       "max": 8
#     },
#     "ols": {
#       "min": 1,
#       "max": 8
#     },
#     "bs": {
#       "min": 1,
#       "max": 16
#     },
#     "instances": {
#       "min": 1,
#       "max": 14
#     }
#   },
#   "initial_values": [
#     {
#       "cores": 1,
#       "mos": 1,
#       "ols": 1,
#       "bs": 1,
#       "instances": 14
#     },
#     {
#       "cores": 2,
#       "mos": 1,
#       "ols": 1,
#       "bs": 1,
#       "instances": 7
#     },
#     {
#       "cores": 4,
#       "mos": 1,
#       "ols": 1,
#       "bs": 1,
#       "instances": 3
#     },
#     {
#       "cores": 7,
#       "mos": 1,
#       "ols": 1,
#       "bs": 1,
#       "instances": 2
#     },
#     {
#       "cores": 14,
#       "mos": 1,
#       "ols": 1,
#       "bs": 1,
#       "instances": 1
#     }
#   ]
# }

# %%
# !python3 /opt/qti-aic/scripts/qaic-model-configurator/model_configurator.py bert_base_cased_onnx/model_fix_outofrange_fp16.onnx onnx \
-onnx-define-symbol=sequence_length,128 -onnx-define-symbol-batch-size=batch_size -multicast-weights -convert-to-fp16\
-optimized-config-search bert_base_dopt.json -max-compilation-threads 8 -time 5 \
-device-id 0 -set-size 1
# Out:
# /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages/paramiko/transport.py:236: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,
# 2023-07-19 12:53:02.118 - [WARNING]: Argument -num-parallel-compile will be deprecated and removed. Please use -max-compilation-threads to set the max number of thread to use when running multiple compilations in parallel.
# 2023-07-19 12:53:02.118 - [INFO]: Starting /opt/qti-aic/scripts/qaic-model-configurator/model_configurator.py bert_base_cased_onnx/model_fix_outofrange_fp16.onnx onnx -onnx-define-symbol=sequence_length,128 -onnx-define-symbol-batch-size=batch_size -multicast-weights -convert-to-fp16 -optimized-config-search bert_base_dopt.json -num-parallel-compile 5 -time 5 -device-id 0 -set-size 1
# 2023-07-19 12:53:02.118 - [INFO]: Model Name: model_fix_outofrange_fp16.onnx
# 2023-07-19 12:53:02.119 - [INFO]: Hostname: ac120r4-08-giga, Physical Cores: 32, Logical Cores: 32, Memory: 125.8 GB
# 2023-07-19 12:53:02.254 - [INFO]: Running optimized search
# [2023-07-19 12:53:02.293] [info] Compiling model with compiler parameters: [(cores=1, mos=[1], ols=1, batchSize=1)]
# [2023-07-19 12:53:13.443] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-1-output with runnerParams (instances=14)
# [2023-07-19 12:53:14.095] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-1-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 12:53:19.262] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-1-output with runnerParams (instances=14)
# [2023-07-19 12:53:19.908] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-1-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 12:53:25.074] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-1-output with runnerParams (instances=14)
# [2023-07-19 12:53:25.708] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-1-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 12:53:30.875] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-1-output with runnerParams (instances=14)
# [2023-07-19 12:53:31.502] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-1-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 12:53:36.666] [info] Compiling model with compiler parameters: [(cores=1, mos=[1], ols=1, batchSize=2), (cores=1, mos=[1], ols=2, batchSize=1)]
# [2023-07-19 12:53:49.813] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-1-output with runnerParams (instances=13)
# [2023-07-19 12:53:50.433] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-1-output with runnerParams (instances=13) running on device ID 0
# [2023-07-19 12:53:55.593] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-2-bs-1-output with runnerParams (instances=14)
# [2023-07-19 12:53:56.209] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-2-bs-1-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 12:54:01.377] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-2-output with runnerParams (instances=14)
# [2023-07-19 12:54:02.011] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-2-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 12:54:07.187] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-1-output with runnerParams (instances=13)
# [2023-07-19 12:54:07.791] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-1-output with runnerParams (instances=13) running on device ID 0
# [2023-07-19 12:54:12.947] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-2-bs-1-output with runnerParams (instances=14)
# [2023-07-19 12:54:13.580] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-2-bs-1-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 12:54:18.747] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-2-output with runnerParams (instances=14)
# [2023-07-19 12:54:19.384] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-2-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 12:54:24.551] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-1-output with runnerParams (instances=13)
# [2023-07-19 12:54:25.152] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-1-output with runnerParams (instances=13) running on device ID 0
# [2023-07-19 12:54:30.311] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-2-bs-1-output with runnerParams (instances=14)
# [2023-07-19 12:54:30.942] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-2-bs-1-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 12:54:36.118] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-2-output with runnerParams (instances=14)
# [2023-07-19 12:54:36.751] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-2-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 12:54:41.929] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-1-output with runnerParams (instances=13)
# [2023-07-19 12:54:42.531] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-1-output with runnerParams (instances=13) running on device ID 0
# [2023-07-19 12:54:47.689] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-2-bs-1-output with runnerParams (instances=14)
# [2023-07-19 12:54:48.364] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-2-bs-1-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 12:54:53.531] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-2-output with runnerParams (instances=14)
# [2023-07-19 12:54:54.159] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-2-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 12:54:59.325] [info] Compiling model with compiler parameters: [(cores=1, mos=[1], ols=1, batchSize=16)]
# [2023-07-19 12:55:25.207] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-16-output with runnerParams (instances=14)
# [2023-07-19 12:55:25.847] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-16-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 12:55:31.525] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-16-output with runnerParams (instances=14)
# [2023-07-19 12:55:32.191] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-16-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 12:55:37.871] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-16-output with runnerParams (instances=14)
# [2023-07-19 12:55:38.527] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-16-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 12:55:44.209] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-16-output with runnerParams (instances=14)
# [2023-07-19 12:55:44.884] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-16-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 12:55:50.555] [info] Compiling model with compiler parameters: [(cores=1, mos=[1], ols=1, batchSize=4)]
# [2023-07-19 12:56:03.457] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-4-output with runnerParams (instances=14)
# [2023-07-19 12:56:04.108] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-4-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 12:56:09.780] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-4-output with runnerParams (instances=14)
# [2023-07-19 12:56:10.428] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-4-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 12:56:15.625] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-4-output with runnerParams (instances=14)
# [2023-07-19 12:56:16.275] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-4-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 12:56:21.951] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-4-output with runnerParams (instances=14)
# [2023-07-19 12:56:22.582] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-4-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 12:56:28.258] [info] Compiling model with compiler parameters: [(cores=1, mos=[1], ols=1, batchSize=8), (cores=1, mos=[1], ols=2, batchSize=4)]
# [2023-07-19 12:56:46.812] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-4-output with runnerParams (instances=13)
# [2023-07-19 12:56:47.445] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-4-output with runnerParams (instances=13) running on device ID 0
# [2023-07-19 12:56:52.661] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-2-bs-4-output with runnerParams (instances=14)
# [2023-07-19 12:56:53.327] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-2-bs-4-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 12:56:58.533] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-8-output with runnerParams (instances=14)
# [2023-07-19 12:56:59.183] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-8-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 12:57:04.407] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-4-output with runnerParams (instances=13)
# [2023-07-19 12:57:05.018] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-4-output with runnerParams (instances=13) running on device ID 0
# [2023-07-19 12:57:10.217] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-2-bs-4-output with runnerParams (instances=14)
# [2023-07-19 12:57:10.869] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-2-bs-4-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 12:57:16.080] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-8-output with runnerParams (instances=14)
# [2023-07-19 12:57:16.732] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-8-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 12:57:21.933] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-4-output with runnerParams (instances=13)
# [2023-07-19 12:57:22.536] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-4-output with runnerParams (instances=13) running on device ID 0
# [2023-07-19 12:57:27.748] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-2-bs-4-output with runnerParams (instances=14)
# [2023-07-19 12:57:28.402] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-2-bs-4-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 12:57:33.599] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-8-output with runnerParams (instances=14)
# [2023-07-19 12:57:34.251] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-8-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 12:57:39.473] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-4-output with runnerParams (instances=13)
# [2023-07-19 12:57:40.076] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-4-output with runnerParams (instances=13) running on device ID 0
# [2023-07-19 12:57:45.284] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-2-bs-4-output with runnerParams (instances=14)
# [2023-07-19 12:57:45.926] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-2-bs-4-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 12:57:51.140] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-8-output with runnerParams (instances=14)
# [2023-07-19 12:57:51.793] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-8-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 12:57:57.003] [info] Compiling model with compiler parameters: [(cores=1, mos=[1], ols=3, batchSize=4)]
# [2023-07-19 12:58:10.954] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-3-bs-4-output with runnerParams (instances=14)
# [2023-07-19 12:58:11.596] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-3-bs-4-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 12:58:16.795] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-3-bs-4-output with runnerParams (instances=14)
# [2023-07-19 12:58:17.441] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-3-bs-4-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 12:58:22.636] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-3-bs-4-output with runnerParams (instances=14)
# [2023-07-19 12:58:23.283] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-3-bs-4-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 12:58:28.477] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-3-bs-4-output with runnerParams (instances=14)
# [2023-07-19 12:58:29.112] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-3-bs-4-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 12:58:34.308] [info] Compiling model with compiler parameters: [(cores=1, mos=[1], ols=5, batchSize=4)]
# [2023-07-19 12:58:49.505] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-5-bs-4-output with runnerParams (instances=14)
# [2023-07-19 12:58:50.158] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-5-bs-4-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 12:58:55.826] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-5-bs-4-output with runnerParams (instances=14)
# [2023-07-19 12:58:56.470] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-5-bs-4-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 12:59:01.674] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-5-bs-4-output with runnerParams (instances=14)
# [2023-07-19 12:59:02.317] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-5-bs-4-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 12:59:07.522] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-5-bs-4-output with runnerParams (instances=14)
# [2023-07-19 12:59:08.159] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-5-bs-4-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 12:59:13.352] [info] Compiling model with compiler parameters: [(cores=1, mos=[1], ols=3, batchSize=2), (cores=1, mos=[1], ols=3, batchSize=8), (cores=1, mos=[1], ols=4, batchSize=4)]
# [2023-07-19 12:59:36.763] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-3-bs-2-output with runnerParams (instances=14)
# [2023-07-19 12:59:37.399] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-3-bs-2-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 12:59:42.574] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-3-bs-4-output with runnerParams (instances=13)
# [2023-07-19 12:59:43.176] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-3-bs-4-output with runnerParams (instances=13) running on device ID 0
# [2023-07-19 12:59:48.387] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-4-bs-4-output with runnerParams (instances=14)
# [2023-07-19 12:59:49.015] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-4-bs-4-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 12:59:54.220] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-3-bs-8-output with runnerParams (instances=14)
# [2023-07-19 12:59:54.863] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-3-bs-8-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 13:00:00.086] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-3-bs-2-output with runnerParams (instances=14)
# [2023-07-19 13:00:00.731] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-3-bs-2-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 13:00:05.896] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-3-bs-4-output with runnerParams (instances=13)
# [2023-07-19 13:00:06.505] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-3-bs-4-output with runnerParams (instances=13) running on device ID 0
# [2023-07-19 13:00:11.705] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-4-bs-4-output with runnerParams (instances=14)
# [2023-07-19 13:00:12.347] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-4-bs-4-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 13:00:17.553] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-3-bs-8-output with runnerParams (instances=14)
# [2023-07-19 13:00:18.188] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-3-bs-8-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 13:00:23.886] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-3-bs-2-output with runnerParams (instances=14)
# [2023-07-19 13:00:24.511] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-3-bs-2-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 13:00:29.679] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-3-bs-4-output with runnerParams (instances=13)
# [2023-07-19 13:00:30.274] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-3-bs-4-output with runnerParams (instances=13) running on device ID 0
# [2023-07-19 13:00:35.482] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-4-bs-4-output with runnerParams (instances=14)
# [2023-07-19 13:00:36.108] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-4-bs-4-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 13:00:41.329] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-3-bs-8-output with runnerParams (instances=14)
# [2023-07-19 13:00:41.959] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-3-bs-8-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 13:00:47.169] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-3-bs-2-output with runnerParams (instances=14)
# [2023-07-19 13:00:47.797] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-3-bs-2-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 13:00:52.970] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-3-bs-4-output with runnerParams (instances=13)
# [2023-07-19 13:00:53.572] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-3-bs-4-output with runnerParams (instances=13) running on device ID 0
# [2023-07-19 13:00:58.780] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-4-bs-4-output with runnerParams (instances=14)
# [2023-07-19 13:00:59.428] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-4-bs-4-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 13:01:04.627] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-3-bs-8-output with runnerParams (instances=14)
# [2023-07-19 13:01:05.265] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-3-bs-8-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 13:01:10.483] [info] Compiling model with compiler parameters: [(cores=1, mos=[1], ols=2, batchSize=16)]
# [2023-07-19 13:01:35.817] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-2-bs-16-output with runnerParams (instances=14)
# [2023-07-19 13:01:36.456] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-2-bs-16-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 13:01:42.134] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-2-bs-16-output with runnerParams (instances=14)
# [2023-07-19 13:01:42.783] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-2-bs-16-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 13:01:48.473] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-2-bs-16-output with runnerParams (instances=14)
# [2023-07-19 13:01:49.124] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-2-bs-16-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 13:01:54.800] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-2-bs-16-output with runnerParams (instances=14)
# [2023-07-19 13:01:55.428] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-2-bs-16-output with runnerParams (instances=14) running on device ID 0
# [2023-07-19 13:02:01.109] [info] Compiling model with compiler parameters: [(cores=2, mos=[1], ols=1, batchSize=1)]
# [2023-07-19 13:02:15.491] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-1-output with runnerParams (instances=7)
# [2023-07-19 13:02:15.931] [info] Model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-1-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:02:21.039] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-1-output with runnerParams (instances=7)
# [2023-07-19 13:02:21.461] [info] Model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-1-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:02:26.564] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-1-output with runnerParams (instances=7)
# [2023-07-19 13:02:26.976] [info] Model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-1-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:02:32.083] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-1-output with runnerParams (instances=7)
# [2023-07-19 13:02:32.497] [info] Model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-1-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:02:37.604] [info] Compiling model with compiler parameters: [(cores=2, mos=[1], ols=1, batchSize=2), (cores=2, mos=[1], ols=2, batchSize=1), (cores=2, mos=[2], ols=1, batchSize=1)]
# [2023-07-19 13:03:02.430] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-1-output with runnerParams (instances=7)
# [2023-07-19 13:03:02.871] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-1-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:03:07.969] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-1-output with runnerParams (instances=6)
# [2023-07-19 13:03:08.371] [info] Model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-1-output with runnerParams (instances=6) running on device ID 0
# [2023-07-19 13:03:13.466] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-2-mos-2-ols-1-bs-1-output with runnerParams (instances=7)
# [2023-07-19 13:03:13.889] [info] Model at path model_configurator_output/compiled_models/qpc-cores-2-mos-2-ols-1-bs-1-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:03:18.991] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-2-bs-1-output with runnerParams (instances=7)
# [2023-07-19 13:03:19.412] [info] Model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-2-bs-1-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:03:24.520] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-2-output with runnerParams (instances=7)
# [2023-07-19 13:03:24.964] [info] Model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-2-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:03:30.066] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-1-output with runnerParams (instances=7)
# [2023-07-19 13:03:30.485] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-1-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:03:35.582] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-1-output with runnerParams (instances=6)
# [2023-07-19 13:03:35.969] [info] Model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-1-output with runnerParams (instances=6) running on device ID 0
# [2023-07-19 13:03:41.061] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-2-mos-2-ols-1-bs-1-output with runnerParams (instances=7)
# [2023-07-19 13:03:41.486] [info] Model at path model_configurator_output/compiled_models/qpc-cores-2-mos-2-ols-1-bs-1-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:03:46.589] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-2-bs-1-output with runnerParams (instances=7)
# [2023-07-19 13:03:47.016] [info] Model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-2-bs-1-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:03:52.118] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-2-output with runnerParams (instances=7)
# [2023-07-19 13:03:52.551] [info] Model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-2-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:03:57.655] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-1-output with runnerParams (instances=7)
# [2023-07-19 13:03:58.065] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-1-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:04:03.167] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-1-output with runnerParams (instances=6)
# [2023-07-19 13:04:03.563] [info] Model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-1-output with runnerParams (instances=6) running on device ID 0
# [2023-07-19 13:04:08.656] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-2-mos-2-ols-1-bs-1-output with runnerParams (instances=7)
# [2023-07-19 13:04:09.085] [info] Model at path model_configurator_output/compiled_models/qpc-cores-2-mos-2-ols-1-bs-1-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:04:14.193] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-2-bs-1-output with runnerParams (instances=7)
# [2023-07-19 13:04:14.626] [info] Model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-2-bs-1-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:04:19.729] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-2-output with runnerParams (instances=7)
# [2023-07-19 13:04:20.169] [info] Model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-2-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:04:25.273] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-1-output with runnerParams (instances=7)
# [2023-07-19 13:04:25.689] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-1-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:04:30.789] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-1-output with runnerParams (instances=6)
# [2023-07-19 13:04:31.184] [info] Model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-1-output with runnerParams (instances=6) running on device ID 0
# [2023-07-19 13:04:36.276] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-2-mos-2-ols-1-bs-1-output with runnerParams (instances=7)
# [2023-07-19 13:04:36.703] [info] Model at path model_configurator_output/compiled_models/qpc-cores-2-mos-2-ols-1-bs-1-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:04:41.810] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-2-bs-1-output with runnerParams (instances=7)
# [2023-07-19 13:04:42.245] [info] Model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-2-bs-1-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:04:47.350] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-2-output with runnerParams (instances=7)
# [2023-07-19 13:04:47.786] [info] Model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-2-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:04:52.901] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-8-output with runnerParams (instances=7)
# [2023-07-19 13:04:53.330] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-8-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:04:58.931] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-8-output with runnerParams (instances=7)
# [2023-07-19 13:04:59.370] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-8-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:05:04.974] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-8-output with runnerParams (instances=7)
# [2023-07-19 13:05:05.399] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-8-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:05:11.004] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-8-output with runnerParams (instances=7)
# [2023-07-19 13:05:11.434] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-8-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:05:17.039] [info] Compiling model with compiler parameters: [(cores=1, mos=[1], ols=2, batchSize=8), (cores=2, mos=[1], ols=1, batchSize=8)]
# [2023-07-19 13:05:38.469] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-4-output with runnerParams (instances=7)
# [2023-07-19 13:05:38.887] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-4-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:05:44.485] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-8-output with runnerParams (instances=6)
# [2023-07-19 13:05:44.882] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-8-output with runnerParams (instances=6) running on device ID 0
# [2023-07-19 13:05:50.468] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-8-output with runnerParams (instances=7)
# [2023-07-19 13:05:50.891] [info] Model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-8-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:05:56.495] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-2-bs-8-output with runnerParams (instances=7)
# [2023-07-19 13:05:56.901] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-2-bs-8-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:06:02.504] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-16-output with runnerParams (instances=7)
# [2023-07-19 13:06:02.923] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-16-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:06:08.527] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-8-output with runnerParams (instances=8)
# [2023-07-19 13:06:09.001] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-8-output with runnerParams (instances=8) running on device ID 0
# [2023-07-19 13:06:14.625] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-4-output with runnerParams (instances=7)
# [2023-07-19 13:06:15.051] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-4-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:06:20.650] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-8-output with runnerParams (instances=6)
# [2023-07-19 13:06:21.048] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-8-output with runnerParams (instances=6) running on device ID 0
# [2023-07-19 13:06:26.640] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-8-output with runnerParams (instances=7)
# [2023-07-19 13:06:27.066] [info] Model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-8-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:06:32.672] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-2-bs-8-output with runnerParams (instances=7)
# [2023-07-19 13:06:33.079] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-2-bs-8-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:06:38.684] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-16-output with runnerParams (instances=7)
# [2023-07-19 13:06:39.099] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-16-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:06:44.704] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-8-output with runnerParams (instances=8)
# [2023-07-19 13:06:45.157] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-8-output with runnerParams (instances=8) running on device ID 0
# [2023-07-19 13:06:50.766] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-4-output with runnerParams (instances=7)
# [2023-07-19 13:06:51.176] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-4-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:06:56.776] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-8-output with runnerParams (instances=6)
# [2023-07-19 13:06:57.171] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-8-output with runnerParams (instances=6) running on device ID 0
# [2023-07-19 13:07:02.758] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-8-output with runnerParams (instances=7)
# [2023-07-19 13:07:03.179] [info] Model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-8-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:07:08.306] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-2-bs-8-output with runnerParams (instances=7)
# [2023-07-19 13:07:08.713] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-2-bs-8-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:07:14.320] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-16-output with runnerParams (instances=7)
# [2023-07-19 13:07:14.736] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-16-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:07:20.344] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-8-output with runnerParams (instances=8)
# [2023-07-19 13:07:20.796] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-8-output with runnerParams (instances=8) running on device ID 0
# [2023-07-19 13:07:26.406] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-4-output with runnerParams (instances=7)
# [2023-07-19 13:07:26.810] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-4-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:07:32.412] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-8-output with runnerParams (instances=6)
# [2023-07-19 13:07:32.802] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-8-output with runnerParams (instances=6) running on device ID 0
# [2023-07-19 13:07:38.394] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-8-output with runnerParams (instances=7)
# [2023-07-19 13:07:38.817] [info] Model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-8-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:07:44.427] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-2-bs-8-output with runnerParams (instances=7)
# [2023-07-19 13:07:44.831] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-2-bs-8-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:07:50.438] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-16-output with runnerParams (instances=7)
# [2023-07-19 13:07:50.854] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-16-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:07:56.460] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-8-output with runnerParams (instances=8)
# [2023-07-19 13:07:56.907] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-8-output with runnerParams (instances=8) running on device ID 0
# [2023-07-19 13:08:02.520] [info] Compiling model with compiler parameters: [(cores=2, mos=[1], ols=1, batchSize=4), (cores=2, mos=[1], ols=1, batchSize=16), (cores=2, mos=[1], ols=2, batchSize=8), (cores=2, mos=[2], ols=1, batchSize=8)]
# [2023-07-19 13:08:43.978] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-4-output with runnerParams (instances=7)
# [2023-07-19 13:08:44.440] [info] Model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-4-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:08:49.592] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-8-output with runnerParams (instances=6)
# [2023-07-19 13:08:49.980] [info] Model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-8-output with runnerParams (instances=6) running on device ID 0
# [2023-07-19 13:08:55.121] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-2-mos-2-ols-1-bs-8-output with runnerParams (instances=7)
# [2023-07-19 13:08:55.550] [info] Model at path model_configurator_output/compiled_models/qpc-cores-2-mos-2-ols-1-bs-8-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:09:00.684] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-2-bs-8-output with runnerParams (instances=7)
# [2023-07-19 13:09:01.136] [info] Model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-2-bs-8-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:09:06.735] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-16-output with runnerParams (instances=7)
# [2023-07-19 13:09:07.181] [info] Model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-16-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:09:12.818] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-4-output with runnerParams (instances=7)
# [2023-07-19 13:09:13.259] [info] Model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-4-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:09:18.415] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-8-output with runnerParams (instances=6)
# [2023-07-19 13:09:18.805] [info] Model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-8-output with runnerParams (instances=6) running on device ID 0
# [2023-07-19 13:09:23.942] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-2-mos-2-ols-1-bs-8-output with runnerParams (instances=7)
# [2023-07-19 13:09:24.385] [info] Model at path model_configurator_output/compiled_models/qpc-cores-2-mos-2-ols-1-bs-8-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:09:29.528] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-2-bs-8-output with runnerParams (instances=7)
# [2023-07-19 13:09:29.977] [info] Model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-2-bs-8-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:09:35.584] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-16-output with runnerParams (instances=7)
# [2023-07-19 13:09:36.027] [info] Model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-16-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:09:41.672] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-4-output with runnerParams (instances=7)
# [2023-07-19 13:09:42.106] [info] Model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-4-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:09:47.256] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-8-output with runnerParams (instances=6)
# [2023-07-19 13:09:47.653] [info] Model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-1-bs-8-output with runnerParams (instances=6) running on device ID 0
# [2023-07-19 13:09:52.791] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-2-mos-2-ols-1-bs-8-output with runnerParams (instances=7)
# [2023-07-19 13:09:53.228] [info] Model at path model_configurator_output/compiled_models/qpc-cores-2-mos-2-ols-1-bs-8-output with runnerParams (instances=7) running on device ID 0
# [2023-07-19 13:09:58.374] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-2-bs-8-output with runnerParams (instances=7)
# [2023-07-19 13:09:58.813] [info] Model at path model_configurator_output/compiled_models/qpc-cores-2-mos-1-ols-2-bs-8-output with runnerParams (instances=7) running on device ID 0
# ...
# [2023-07-19 14:09:37.485] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-13-mos-1-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-07-19 14:09:37.855] [info] Model at path model_configurator_output/compiled_models/qpc-cores-13-mos-1-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:09:42.899] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-13-mos-1-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-07-19 14:09:43.255] [info] Model at path model_configurator_output/compiled_models/qpc-cores-13-mos-1-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:09:48.302] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-13-mos-1-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-07-19 14:09:48.661] [info] Model at path model_configurator_output/compiled_models/qpc-cores-13-mos-1-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:09:53.707] [info] Compiling model with compiler parameters: [(cores=12, mos=[1], ols=1, batchSize=16), (cores=13, mos=[1], ols=2, batchSize=16), (cores=13, mos=[2], ols=1, batchSize=16), (cores=14, mos=[1], ols=1, batchSize=16)]
# [2023-07-19 14:11:35.162] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-12-mos-1-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-07-19 14:11:35.542] [info] Model at path model_configurator_output/compiled_models/qpc-cores-12-mos-1-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:11:40.594] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-14-mos-1-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-07-19 14:11:40.971] [info] Model at path model_configurator_output/compiled_models/qpc-cores-14-mos-1-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:11:46.014] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-13-mos-2-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-07-19 14:11:46.451] [info] Model at path model_configurator_output/compiled_models/qpc-cores-13-mos-2-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:11:51.503] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-13-mos-1-ols-2-bs-16-output with runnerParams (instances=1)
# [2023-07-19 14:11:51.880] [info] Model at path model_configurator_output/compiled_models/qpc-cores-13-mos-1-ols-2-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:11:56.930] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-12-mos-1-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-07-19 14:11:57.303] [info] Model at path model_configurator_output/compiled_models/qpc-cores-12-mos-1-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:12:02.348] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-14-mos-1-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-07-19 14:12:02.718] [info] Model at path model_configurator_output/compiled_models/qpc-cores-14-mos-1-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:12:07.766] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-13-mos-2-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-07-19 14:12:08.199] [info] Model at path model_configurator_output/compiled_models/qpc-cores-13-mos-2-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:12:13.249] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-13-mos-1-ols-2-bs-16-output with runnerParams (instances=1)
# [2023-07-19 14:12:13.624] [info] Model at path model_configurator_output/compiled_models/qpc-cores-13-mos-1-ols-2-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:12:18.668] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-12-mos-1-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-07-19 14:12:19.045] [info] Model at path model_configurator_output/compiled_models/qpc-cores-12-mos-1-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:12:24.089] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-14-mos-1-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-07-19 14:12:24.453] [info] Model at path model_configurator_output/compiled_models/qpc-cores-14-mos-1-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:12:29.495] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-13-mos-2-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-07-19 14:12:29.904] [info] Model at path model_configurator_output/compiled_models/qpc-cores-13-mos-2-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:12:34.955] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-13-mos-1-ols-2-bs-16-output with runnerParams (instances=1)
# [2023-07-19 14:12:35.323] [info] Model at path model_configurator_output/compiled_models/qpc-cores-13-mos-1-ols-2-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:12:40.367] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-12-mos-1-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-07-19 14:12:40.729] [info] Model at path model_configurator_output/compiled_models/qpc-cores-12-mos-1-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:12:45.778] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-14-mos-1-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-07-19 14:12:46.141] [info] Model at path model_configurator_output/compiled_models/qpc-cores-14-mos-1-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:12:51.184] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-13-mos-2-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-07-19 14:12:51.597] [info] Model at path model_configurator_output/compiled_models/qpc-cores-13-mos-2-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:12:56.650] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-13-mos-1-ols-2-bs-16-output with runnerParams (instances=1)
# [2023-07-19 14:12:57.020] [info] Model at path model_configurator_output/compiled_models/qpc-cores-13-mos-1-ols-2-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:13:02.071] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-07-19 14:13:02.306] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:13:07.854] [info] Compiling model with compiler parameters: [(cores=10, mos=[1], ols=1, batchSize=16)]
# [2023-07-19 14:13:43.091] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-10-mos-1-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-07-19 14:13:43.384] [info] Model at path model_configurator_output/compiled_models/qpc-cores-10-mos-1-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:13:48.428] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-10-mos-1-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-07-19 14:13:48.715] [info] Model at path model_configurator_output/compiled_models/qpc-cores-10-mos-1-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:13:53.757] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-10-mos-1-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-07-19 14:13:54.029] [info] Model at path model_configurator_output/compiled_models/qpc-cores-10-mos-1-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:13:59.074] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-10-mos-1-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-07-19 14:13:59.345] [info] Model at path model_configurator_output/compiled_models/qpc-cores-10-mos-1-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:14:04.393] [info] Compiling model with compiler parameters: [(cores=11, mos=[1], ols=1, batchSize=16), (cores=12, mos=[1], ols=1, batchSize=8), (cores=12, mos=[1], ols=2, batchSize=16), (cores=12, mos=[2], ols=1, batchSize=16)]
# [2023-07-19 14:15:46.303] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-11-mos-1-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-07-19 14:15:46.639] [info] Model at path model_configurator_output/compiled_models/qpc-cores-11-mos-1-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:15:51.683] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-12-mos-1-ols-1-bs-8-output with runnerParams (instances=1)
# [2023-07-19 14:15:52.065] [info] Model at path model_configurator_output/compiled_models/qpc-cores-12-mos-1-ols-1-bs-8-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:15:57.113] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-12-mos-2-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-07-19 14:15:57.386] [info] Model at path model_configurator_output/compiled_models/qpc-cores-12-mos-2-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:16:02.435] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-12-mos-1-ols-2-bs-16-output with runnerParams (instances=1)
# [2023-07-19 14:16:02.798] [info] Model at path model_configurator_output/compiled_models/qpc-cores-12-mos-1-ols-2-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:16:07.843] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-11-mos-1-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-07-19 14:16:08.173] [info] Model at path model_configurator_output/compiled_models/qpc-cores-11-mos-1-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:16:13.214] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-12-mos-1-ols-1-bs-8-output with runnerParams (instances=1)
# [2023-07-19 14:16:13.587] [info] Model at path model_configurator_output/compiled_models/qpc-cores-12-mos-1-ols-1-bs-8-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:16:18.632] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-12-mos-2-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-07-19 14:16:18.905] [info] Model at path model_configurator_output/compiled_models/qpc-cores-12-mos-2-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:16:23.953] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-12-mos-1-ols-2-bs-16-output with runnerParams (instances=1)
# [2023-07-19 14:16:24.310] [info] Model at path model_configurator_output/compiled_models/qpc-cores-12-mos-1-ols-2-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:16:29.354] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-11-mos-1-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-07-19 14:16:29.673] [info] Model at path model_configurator_output/compiled_models/qpc-cores-11-mos-1-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:16:34.717] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-12-mos-1-ols-1-bs-8-output with runnerParams (instances=1)
# [2023-07-19 14:16:35.083] [info] Model at path model_configurator_output/compiled_models/qpc-cores-12-mos-1-ols-1-bs-8-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:16:40.129] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-12-mos-2-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-07-19 14:16:40.394] [info] Model at path model_configurator_output/compiled_models/qpc-cores-12-mos-2-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:16:45.437] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-12-mos-1-ols-2-bs-16-output with runnerParams (instances=1)
# [2023-07-19 14:16:45.790] [info] Model at path model_configurator_output/compiled_models/qpc-cores-12-mos-1-ols-2-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:16:50.837] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-11-mos-1-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-07-19 14:16:51.151] [info] Model at path model_configurator_output/compiled_models/qpc-cores-11-mos-1-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:16:56.195] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-12-mos-1-ols-1-bs-8-output with runnerParams (instances=1)
# [2023-07-19 14:16:56.560] [info] Model at path model_configurator_output/compiled_models/qpc-cores-12-mos-1-ols-1-bs-8-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:17:01.602] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-12-mos-2-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-07-19 14:17:01.917] [info] Model at path model_configurator_output/compiled_models/qpc-cores-12-mos-2-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:17:06.965] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-12-mos-1-ols-2-bs-16-output with runnerParams (instances=1)
# [2023-07-19 14:17:07.319] [info] Model at path model_configurator_output/compiled_models/qpc-cores-12-mos-1-ols-2-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-07-19 14:17:12.370] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-2-bs-16-output with runnerParams (instances=1)
# [2023-07-19 14:17:12.600] [info] Model at path model_configurator_output/compiled_models/qpc-cores-1-mos-1-ols-2-bs-16-output with runnerParams (instances=1) running on device ID 0
# 2023-07-19 14:17:20.477 - [INFO]: Optimized search results:
#   OptimizerStatus                      InitialValue                      cores mos   ols  batchSize  instances  Objective (inf/sec)
# 0      SUCCESS     (cores=1, mos=[1], ols=1, batchSize=1, instances=14)    1    [1]   3       4         14            2367.03
# 1      SUCCESS      (cores=2, mos=[1], ols=1, batchSize=1, instances=7)    2    [1]   4       8          7            2504.47
# 2      SUCCESS      (cores=4, mos=[1], ols=1, batchSize=1, instances=3)    4    [1]   3      16          3            2134.11
# 3      SUCCESS      (cores=7, mos=[1], ols=1, batchSize=1, instances=2)    6    [1]   2      16          2            1591.20
# 4      SUCCESS     (cores=14, mos=[1], ols=1, batchSize=1, instances=1)   12    [1]   1      16          1            1176.24
# 2023-07-19 14:17:20.479 - [INFO]: Total execution time 01:24:18.363

# %% [markdown]
# ## Measure end-to-end latency
#
# Here are the steps to measure the end-to-end latency as well as the breakdown of latency for the best configuration identified in the previous step.
#
# 1. Compile the model using 'qaic-exec'with the configuration parameters identified in previous step using model configurator.
# 2. Execute the compiled model using 'qaic-runner' with the run time parameters identified in previous step using model configurator. Run 'qaic-runner' with flags that dump latency information.
# 3. Post process the latency information to identify percentile distribution (mean, median, 95 and 99) in latency across inferences.

# %%
## Compile the model 

# !rm -rf compiled_fp16
# !/opt/qti-aic/exec/qaic-exec -v -aic-hw  -convert-to-fp16 \
-mos=1 -ols=4 -aic-num-cores=2 \
-m=bert_base_cased_onnx/model_fix_outofrange_fp16.onnx \
-onnx-define-symbol=sequence_length,128 -onnx-define-symbol=batch_size,8 \
-multicast-weights -stats-batchsize=8 -aic-binary-dir=./compiled_fp16 \
-aic-hw-version=2.0 -compile-only
# Out:
# Reading ONNX Model from bert_base_cased_onnx/model_fix_outofrange_fp16.onnx
# Compile started ...............
# Compiling model with FP16 precision.
# AIC WARNING: MAC estimate does not yet handle all operations
# Original MAC estimate: 18446744060020916224
# Original Graph operation size histogram:
# output elts    op count (cumulative)
#        1024                  13   2%
#        2048                  15   2%
#      786432                 333  64%
#     1572864                 420  81%
#     3145728                 516 100%
# preD32 constants size: 342228040 B
# AIC HMX MAC estimate:  18446744060044509184
# AIC non-HMX MAC estimate:  0
# d32 constants size: 215076032 B
# final constants size: 215076032 B
# Using VTCM alg: NOT fatness reduced first fit reset
# MulticastTableSize: 7
# VTCM0Size:   8372224 B
# VTCM1Size:   8372224 B
# VTCMMaxSize: 8372224 B
# StaticSharedDDRSize: 	           0 B
# DynamicSharedDDRSize: 	           0 B
# StaticConstantsSize: 	   215076864 B
# DynamicConstantsSize: 	           0 B
# Constants size: 215076864 (bytes)
# QAicGraph
# Compiler estimated memory traffic:
# Port info:
#  port01: host input
#  port02: host outut
#    host: DDR traffic  read:          0 KB (first-inf          0 KB)
#              constant only:          0 KB (first-inf          0 KB)
#     c00: DDR traffic  read:      83957 KB (first-inf      83957 KB)
#              constant only:      83957 KB (first-inf      83957 KB)
#     c01: DDR traffic  read:      84312 KB (first-inf      84312 KB)
#              constant only:      84312 KB (first-inf      84312 KB)
#    host: DDR traffic write:          0 KB
#     c00: DDR traffic write:          0 KB
#     c01: DDR traffic write:          0 KB
#    host: MC  traffic  read:          4 KB
#  port02: MC  traffic  read:          4 KB
#     c00: MC  traffic  read:          0 KB
#     c01: MC  traffic  read:          0 KB
#    host: MC  traffic write:         12 KB
#  port01: MC  traffic write:         12 KB
#     c00: MC  traffic write:      83192 KB
#     c00:     constant only:        244 KB
#     c01: MC  traffic write:      83354 KB
#     c01:     constant only:        408 KB
#   total: DDR traffic  read:     168269 KB (first-inf     168269 KB)
#              constant only:     168269 KB (first-inf     168269 KB)
#   total: DDR traffic write:          0 KB
#   total: MC  traffic  read:          4 KB
#   total: MC  traffic write:     166558 KB
#   total:     constant only:        652 KB
#   c00 barriers:          0
#   c01 barriers:          0
# Number of specialized kernels: 50
# Number of shared specialized kernels: 15876
# ELF sections size: 642392 (bytes)
# Generated binary is present at ./compiled_fp16

# %%
## Execute the compiled model with the latency flags 
# !mkdir bert_base_cased_stats
# !/opt/qti-aic/exec/qaic-runner --test-data ./compiled_fp16  -d 0 -S 1 -a 7 \
--aic-profiling-type latency --aic-profiling-out-dir ./bert_base_cased_stats \
--aic-profiling-start-iter 100 --aic-profiling-num-samples 99999 --time 20
# Out:
# mkdir: cannot create directory ‘bert_base_cased_stats’: File exists
#  ---- Stats ----
# InferenceCnt 6134 TotalDuration 20018822us BatchSize 8 Inf/Sec 2451.293
# Deleting previous file: ./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Writing file:./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Deleting previous file: ./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Writing file:./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Deleting previous file: ./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Writing file:./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Deleting previous file: ./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Writing file:./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Deleting previous file: ./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Writing file:./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Deleting previous file: ./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Writing file:./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Deleting previous file: ./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Writing file:./bert_base_cased_stats/aic-profiling-program-0-latency.txt

# %% [markdown]
# ### Latency breakdown
#
# The end-to-end inference latency can be broken down into 4 major categories - Application, Linux Runtime (LRT) processing, Kernel mode driver (KMD) processing and Cloud AI device processing.
#
#
# ![Latency Breakdown](Images/Latency.jpg)
#
# **Key Latency Stats** (units in us)
# - *totalRoundtripTime* :Time from point where application (qaic-runner in this case) calls Runtime API and ends where post-processing is complete and control is returned to the application indicating the inference is complete
# - *preProcTime* : Time taken to pre-process the data (model input) on the host
# - *postProc* : Time taken to post-process the data (model output) on the host
# - *execTotal* : Time from inference object being submitted to kernel, completion on hardware and processing is returned to user-space

# %%
## Post process the latency information to identify percentile distribution

# !python3 latency_stats_python3.py ./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Out:
# All activations combined:
#                          mean        min       50%        75%        90%        95%        99%        max
# hostRoundTrip       22.595981  21.966000  22.58000  22.767000  22.931200  23.042200  23.177480  23.351000
# enqTime              0.007646   0.004150   0.00795   0.008710   0.009358   0.009862   0.015340   0.034430
# preProcTime          0.005694   0.003590   0.00559   0.005960   0.006250   0.006410   0.006770   0.007640
# submitTime           0.001367   0.000730   0.00136   0.001410   0.001440   0.001460   0.001542   0.001630
# execTotal           22.641737  22.017186  22.62751  22.815500  22.975227  23.092550  23.224261  23.405304
# exectoVc             0.004871   0.003000   0.00500   0.005000   0.005400   0.006000   0.006000   0.030000
# execToComplete      22.591109  21.962000  22.57200  22.763000  22.927800  23.038200  23.172720  23.346000
# postProc             0.002710   0.001430   0.00272   0.002991   0.003130   0.003180   0.003285   0.023380
# totalRoundtripTime  22.686959  22.048066  22.67545  22.862612  23.021230  23.121959  23.278026  23.454775
# totalRoundtripTime: percentile(99%) = 23.278 ms

# %% [markdown]
# As observed, for the best configuration, throughput of ~2450 inf/sec is observed with a latency of ~23ms per batched (bs=8) inference.

# %% [markdown]
# # <span style='color:Blue'> 5. Identify the least latency configuration </span>
#
# Identifying the least latency configurations requires the users to run a few different combinations of the key parameters.
#
# 1. Set batch size to 1 and set-size to 1.
# 2. Compile and execute the network starting from the max aic-num-cores. Iterate by reducing the aic-num-cores and measuring the latency. Identify the least latency configuration.
# 3. Optional - Change the mos, ols values and compile/execute to check for further reduction in latency.
#
# Lets go through these steps for the bert-base-cased model.

# %%
## compile with max aic-num-cores 
for aic_num_cores in range(14,0,-1):
    # !rm -rf compiled_fp16
    # !rm -rf bert_base_cased_stats/*
    
    # !/opt/qti-aic/exec/qaic-exec -aic-hw  -convert-to-fp16 \
    -mos=1 -ols=1 -aic-num-cores={aic_num_cores} \
    -m=bert_base_cased_onnx/model_fix_outofrange_fp16.onnx \
    -onnx-define-symbol=sequence_length,128 -onnx-define-symbol=batch_size,1 \
    -multicast-weights -stats-batchsize=1 -aic-binary-dir=./compiled_fp16 \
    -aic-hw-version=2.0 -compile-only >/dev/null 

    # !/opt/qti-aic/exec/qaic-runner --test-data ./compiled_fp16  -d 0 -S 1 -a 1 \
    --aic-profiling-type latency --aic-profiling-out-dir ./bert_base_cased_stats \
    --aic-profiling-start-iter 100 --aic-profiling-num-samples 99999 --time 10 | grep "InferenceCnt"
    
    print(f"Configuration: "+ "aic-num-cores= " + str(aic_num_cores))
    # !python3 latency_stats_python3.py ./bert_base_cased_stats/aic-profiling-program-0-latency.txt | grep "totalRoundtripTime:"
# Out:
# InferenceCnt 4722 TotalDuration 10000871us BatchSize 1 Inf/Sec 472.159
# Configuration: aic-num-cores= 14
# totalRoundtripTime: percentile(99%) = 2.203 ms
# InferenceCnt 4598 TotalDuration 10000516us BatchSize 1 Inf/Sec 459.776
# Configuration: aic-num-cores= 13
# totalRoundtripTime: percentile(99%) = 2.247 ms
# InferenceCnt 3807 TotalDuration 10001155us BatchSize 1 Inf/Sec 380.656
# Configuration: aic-num-cores= 12
# totalRoundtripTime: percentile(99%) = 2.625 ms
# InferenceCnt 4492 TotalDuration 10000944us BatchSize 1 Inf/Sec 449.158
# Configuration: aic-num-cores= 11
# totalRoundtripTime: percentile(99%) = 2.293 ms
# InferenceCnt 4457 TotalDuration 10001788us BatchSize 1 Inf/Sec 445.620
# Configuration: aic-num-cores= 10
# totalRoundtripTime: percentile(99%) = 2.338 ms
# InferenceCnt 4510 TotalDuration 10000437us BatchSize 1 Inf/Sec 450.980
# Configuration: aic-num-cores= 9
# totalRoundtripTime: percentile(99%) = 2.323 ms
# InferenceCnt 3328 TotalDuration 10002831us BatchSize 1 Inf/Sec 332.706
# Configuration: aic-num-cores= 8
# totalRoundtripTime: percentile(99%) = 3.250 ms
# InferenceCnt 4211 TotalDuration 10001262us BatchSize 1 Inf/Sec 421.047
# Configuration: aic-num-cores= 7
# totalRoundtripTime: percentile(99%) = 2.365 ms
# InferenceCnt 4457 TotalDuration 10002145us BatchSize 1 Inf/Sec 445.604
# Configuration: aic-num-cores= 6
# totalRoundtripTime: percentile(99%) = 2.333 ms
# InferenceCnt 3771 TotalDuration 10001818us BatchSize 1 Inf/Sec 377.031
# Configuration: aic-num-cores= 5
# totalRoundtripTime: percentile(99%) = 2.638 ms
# InferenceCnt 2530 TotalDuration 10003234us BatchSize 1 Inf/Sec 252.918
# Configuration: aic-num-cores= 4
# totalRoundtripTime: percentile(99%) = 3.928 ms
# InferenceCnt 2184 TotalDuration 10000656us BatchSize 1 Inf/Sec 218.386
# Configuration: aic-num-cores= 3
# totalRoundtripTime: percentile(99%) = 4.567 ms
# InferenceCnt 1731 TotalDuration 10004329us BatchSize 1 Inf/Sec 173.025
# Configuration: aic-num-cores= 2
# totalRoundtripTime: percentile(99%) = 5.896 ms
# InferenceCnt 1534 TotalDuration 10006010us BatchSize 1 Inf/Sec 153.308
# Configuration: aic-num-cores= 1
# totalRoundtripTime: percentile(99%) = 6.637 ms

# %% [markdown]
# A few insights from the above results
# - aic-num-cores = 14 (max) delivers the least latency
# - aic-num-cores >= 6 delivers close to the least latency. Using aic-num-cores = 7, lets deploy 2 instances of the compiled network to see if latency stays the same while throughput improves.

# %%
## aic-num-cores =7 and instances = 2
# !rm -rf compiled_fp16
# !rm -rf bert_base_cased_stats/*

# !/opt/qti-aic/exec/qaic-exec -aic-hw  -convert-to-fp16 \
-mos=1 -ols=1 -aic-num-cores=7 \
-m=bert_base_cased_onnx/model_fix_outofrange_fp16.onnx \
-onnx-define-symbol=sequence_length,128 -onnx-define-symbol=batch_size,1 \
-aic-perf-metrics -multicast-weights -stats-batchsize=1 -aic-binary-dir=./compiled_fp16 \
-aic-hw-version=2.0 -compile-only >/dev/null 

# !/opt/qti-aic/exec/qaic-runner --test-data ./compiled_fp16  -d 0 -S 1 -a 2 \
--aic-profiling-type latency --aic-profiling-out-dir ./bert_base_cased_stats \
--aic-profiling-start-iter 100 --aic-profiling-num-samples 99999 --time 20 | grep "InferenceCnt"

# !python3 latency_stats_python3.py ./bert_base_cased_stats/aic-profiling-program-0-latency.txt | grep "totalRoundtripTime:"
# Out:
# Using VTCM alg: NOT fatness reduced Coloring
# InferenceCnt 14008 TotalDuration 20002653us BatchSize 1 Inf/Sec 700.307
# Deleting previous file: ./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# totalRoundtripTime: percentile(99%) = 3.017 ms

# %% [markdown]
# By running 2 instances, the latency increases to ~3ms (from ~2.3ms) and throughput increases to 700 inf/s (from 445 infs/s). If 3ms latency meets the latency target, then we have a configuration with higher throughput.
