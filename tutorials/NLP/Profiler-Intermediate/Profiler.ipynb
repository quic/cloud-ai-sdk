# %% [markdown]
# Copyright (c) 2023 Qualcomm Innovation Center, Inc. All rights reserved. <br>
# SPDX-License-Identifier: BSD-3-Clause-Clear

# %% [markdown]
# **Takeaways** : Users will learn to profile inferences running on Cloud AI 100 at a system and device level <br><br>
# **Before you start** : Some commands (folder locations etc) will need to be updated based on the platform and installation locations. 'Sudo' prefix might be required for some commands to run properly. <br> This notebook assumes that the user understands how to onboard a model, compile and run using qaic-exec and qaic-runner (AIC native tools) respectively. <br>
# The terms 'model' and 'network' are used interchangeably in this notebook.
# The terms 'NSP' and 'AI compute core" are used interchangeably in this notebook.
#
# **Last Verified Qualcomm Cloud AI Platform SDK and Apps SDK Version:** Platform SDK 1.10.0.193 and Apps SDK 1.10.0.193

# %% [markdown]
# # <span style='color:Blue'> Profiling Inferences </span>
#
# ##  Pre-requisite reading
# New users on Cloud AI platforms are expected to have a good understanding of the compilation (qaic-exec) and inference (qaic-runner, qaic-api-test) execution tools.
#
# ## Introduction
# This notebook will cover inference profiling at system and device level using the 'bert-base-cased' model from HuggingFace.
#
# Here is the workflow that will be demonstrated in this notebook.
#
# 1. **Install required packages and download the model**: Begin by installing the required packages and downloading the model.
# 2. **Device health check**: Query the device health using qaic-util tool.
# 3. **Device-level profiling** :
#     - Compiler estimation of the resources used on device.
#     - Summary of the operators, its count and device cycles used.
#     - Detailed timeline view of inference execution on device
# 4. **System-level profiling**: Breakdown the inference time at system level - application, linux runtime, kernel and device.

# %% [markdown]
# # <span style='color:Blue'> 1. Install required packages and download the model </span>
#
# We will install the required Python packages

# %%
import sys
sys.executable
# Out:
# '/opt/qti-aic/dev/python/qaic-env/bin/python'

# %%
# !/opt/qti-aic/dev/python/qaic-env/bin/pip install -r requirements.txt
# Out:
# Requirement already satisfied: onnx==1.12.0 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from -r requirements.txt (line 1)) (1.12.0)
# Requirement already satisfied: optimum in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from -r requirements.txt (line 2)) (1.10.1)
# Requirement already satisfied: numpy==1.23.4 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from -r requirements.txt (line 3)) (1.23.4)
# Requirement already satisfied: onnxruntime in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from -r requirements.txt (line 4)) (1.12.1)
# Requirement already satisfied: torch===1.11.0 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from -r requirements.txt (line 5)) (1.11.0)
# Requirement already satisfied: pillow==8.3.2 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from -r requirements.txt (line 6)) (8.3.2)
# Requirement already satisfied: opencv-python in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from -r requirements.txt (line 7)) (4.5.2.52)
# Requirement already satisfied: paramiko in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from -r requirements.txt (line 8)) (2.10.4)
# Requirement already satisfied: protobuf<=3.20.1,>=3.12.2 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from onnx==1.12.0->-r requirements.txt (line 1)) (3.20.1)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from onnx==1.12.0->-r requirements.txt (line 1)) (4.7.1)
# Requirement already satisfied: coloredlogs in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from optimum->-r requirements.txt (line 2)) (15.0.1)
# Requirement already satisfied: sympy in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from optimum->-r requirements.txt (line 2)) (1.10.1)
# Requirement already satisfied: transformers[sentencepiece]>=4.26.0 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from optimum->-r requirements.txt (line 2)) (4.31.0)
# Requirement already satisfied: packaging in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from optimum->-r requirements.txt (line 2)) (23.1)
# Requirement already satisfied: huggingface-hub>=0.8.0 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from optimum->-r requirements.txt (line 2)) (0.16.4)
# Requirement already satisfied: datasets in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from optimum->-r requirements.txt (line 2)) (2.7.0)
# Requirement already satisfied: flatbuffers in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from onnxruntime->-r requirements.txt (line 4)) (1.12)
# Requirement already satisfied: bcrypt>=3.1.3 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from paramiko->-r requirements.txt (line 8)) (4.0.1)
# Requirement already satisfied: cryptography>=2.5 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from paramiko->-r requirements.txt (line 8)) (41.0.2)
# Requirement already satisfied: pynacl>=1.0.1 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from paramiko->-r requirements.txt (line 8)) (1.5.0)
# Requirement already satisfied: six in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from paramiko->-r requirements.txt (line 8)) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from cryptography>=2.5->paramiko->-r requirements.txt (line 8)) (1.15.1)
# Requirement already satisfied: filelock in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from huggingface-hub>=0.8.0->optimum->-r requirements.txt (line 2)) (3.12.2)
# Requirement already satisfied: fsspec in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from huggingface-hub>=0.8.0->optimum->-r requirements.txt (line 2)) (2023.6.0)
# Requirement already satisfied: requests in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from huggingface-hub>=0.8.0->optimum->-r requirements.txt (line 2)) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from huggingface-hub>=0.8.0->optimum->-r requirements.txt (line 2)) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from huggingface-hub>=0.8.0->optimum->-r requirements.txt (line 2)) (5.4.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from transformers[sentencepiece]>=4.26.0->optimum->-r requirements.txt (line 2)) (2023.6.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from transformers[sentencepiece]>=4.26.0->optimum->-r requirements.txt (line 2)) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from transformers[sentencepiece]>=4.26.0->optimum->-r requirements.txt (line 2)) (0.3.1)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from transformers[sentencepiece]>=4.26.0->optimum->-r requirements.txt (line 2)) (0.1.98)
# Requirement already satisfied: humanfriendly>=9.1 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from coloredlogs->optimum->-r requirements.txt (line 2)) (10.0)
# Requirement already satisfied: pyarrow>=6.0.0 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from datasets->optimum->-r requirements.txt (line 2)) (12.0.1)
# Requirement already satisfied: dill<0.3.7 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from datasets->optimum->-r requirements.txt (line 2)) (0.3.6)
# Requirement already satisfied: pandas in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from datasets->optimum->-r requirements.txt (line 2)) (1.4.3)
# Requirement already satisfied: xxhash in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from datasets->optimum->-r requirements.txt (line 2)) (3.2.0)
# Requirement already satisfied: multiprocess in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from datasets->optimum->-r requirements.txt (line 2)) (0.70.14)
# Requirement already satisfied: aiohttp in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from datasets->optimum->-r requirements.txt (line 2)) (3.8.5)
# Requirement already satisfied: responses<0.19 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from datasets->optimum->-r requirements.txt (line 2)) (0.18.0)
# Requirement already satisfied: mpmath>=0.19 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from sympy->optimum->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: pycparser in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from cffi>=1.12->cryptography>=2.5->paramiko->-r requirements.txt (line 8)) (2.21)
# Requirement already satisfied: attrs>=17.3.0 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from aiohttp->datasets->optimum->-r requirements.txt (line 2)) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from aiohttp->datasets->optimum->-r requirements.txt (line 2)) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from aiohttp->datasets->optimum->-r requirements.txt (line 2)) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from aiohttp->datasets->optimum->-r requirements.txt (line 2)) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from aiohttp->datasets->optimum->-r requirements.txt (line 2)) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from aiohttp->datasets->optimum->-r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from aiohttp->datasets->optimum->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from requests->huggingface-hub>=0.8.0->optimum->-r requirements.txt (line 2)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from requests->huggingface-hub>=0.8.0->optimum->-r requirements.txt (line 2)) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from requests->huggingface-hub>=0.8.0->optimum->-r requirements.txt (line 2)) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from pandas->datasets->optimum->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/qti-aic/dev/python/qaic-env/lib/python3.8/site-packages (from pandas->datasets->optimum->-r requirements.txt (line 2)) (2023.3)

# %%
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"
# !/opt/qti-aic/dev/python/qaic-env/bin/optimum-cli export onnx --model bert-base-cased --cache_dir model_files/cased --opset 11 --task question-answering bert_base_cased_onnx/
# Out:
# 2023-07-31 20:40:05.868379: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-07-31 20:40:05.868405: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Framework not specified. Using pt to export to ONNX.
# Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['qa_outputs.weight', 'qa_outputs.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Using framework PyTorch: 1.11.0+cu102
# Overriding 1 configuration item(s)
# 	- use_cache -> False
# Post-processing the exported models...
# Validating models in subprocesses...
# 2023-07-31 20:40:20.848526: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-07-31 20:40:20.848554: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Validating ONNX model bert_base_cased_onnx/model.onnx...
# 	-[✓] ONNX model output names match reference model (end_logits, start_logits)
# 	- Validating ONNX Model output "start_logits":
# 		-[✓] (2, 16) matches (2, 16)
# 		-[✓] all values close (atol: 0.0001)
# 	- Validating ONNX Model output "end_logits":
# 		-[✓] (2, 16) matches (2, 16)
# 		-[✓] all values close (atol: 0.0001)
# The ONNX export succeeded and the exported model was saved at: bert_base_cased_onnx

# %%
## Clip the constant (used to represent -inf) out of FP16 range to FP16.   

import numpy as np
import onnx
from onnx import numpy_helper
        
def fix_onnx_fp16(
    gen_models_path: str,
    model_base_name: str,
) -> str:
    finfo = np.finfo(np.float16)
    fp16_max = finfo.max
    fp16_min = finfo.min

    model = onnx.load(f"{gen_models_path}/{model_base_name}.onnx")
    fp16_fix = False
    for tensor in onnx.external_data_helper._get_all_tensors(model):
        nptensor = numpy_helper.to_array(tensor, gen_models_path)
        if nptensor.dtype == np.float32 and (
            np.any(nptensor > fp16_max) or np.any(nptensor < fp16_min)
        ):
            print(f'tensor value : {nptensor} above {fp16_max} or below {fp16_min}')
            nptensor = np.clip(nptensor, fp16_min, fp16_max)
            new_tensor = numpy_helper.from_array(nptensor, tensor.name)
            tensor.CopyFrom(new_tensor)
            fp16_fix = True
            
    if fp16_fix:
        # Save FP16 model
        print("Found constants out of FP16 range, clipped to FP16 range")
        model_base_name += "_fix_outofrange_fp16"
        onnx.save(model, f=f"{gen_models_path}/{model_base_name}.onnx")
        print(f"Saving modified onnx file at {gen_models_path}/{model_base_name}.onnx")
    return model_base_name

fp16_model_name = fix_onnx_fp16(gen_models_path="bert_base_cased_onnx", model_base_name="model")
# Out:
# tensor value : -3.4028234663852886e+38 above 65504.0 or below -65504.0
# Found constants out of FP16 range, clipped to FP16 range
# Saving modified onnx file at bert_base_cased_onnx/model_fix_outofrange_fp16.onnx

# %% [markdown]
# # <span style='color:Blue'>2. Check Device Health </span>
#
# 'qaic-util' tool can be used to query the health of all the Cloud AI cards in the server.
#
# "Status: Ready" indicates that the health of the cards is good.
#
# "Status: Error" indicates that the cards are not in good health and a system administrator needs to be contacted to rectify the issue.

# %%
# !/opt/qti-aic/tools/qaic-util -q | grep "Status"
# Out:
# 	Status:Ready
# 	Status:Ready
# 	Status:Ready
# 	Status:Ready
# 	Status:Ready
# 	Status:Ready
# 	Status:Ready
# 	Status:Ready

# %% [markdown]
# # <span style='color:Blue'>3. Device Level Profiling - Compiler Opstats </span>
#
# The Compiler Operator Trace (OpStat) feature allows capturing of network operator trace information from the NSP AI cores combined with QAic Linux Runtime and QAic Kernel events from the host. The combined trace shows a timeline view of host processing along with operator execution and synchronization delays. To enable operator traces, the following parameters need to be added. The number of samples aic-profiling-num-samples and starting iteration aic-profiling-start-iter can be adjusted. The profiling output directory aic-profiling-out-dir must exist.
#
# **qaic-exec**: -aic-profiling-type=stats
# -aic-profiling-type=trace
# -aic-profiling-type=latency
# -aic-perf-metrics : prints an outline of the resource usage of the compiled network
#
# **qaic-runner**: aic-profiling-type : latency
# aic-profiling-out-dir : output directory for latency capture (needs to exist before this command is run)
# aic-profiling-start-iter : Set this value high enough to start capturing samples after device warmup (~250mS)
# aic-profiling-num-samples : # of samples to be captured. Can be set greater than # of inferences
#
# **Sequence of Steps to be run**
#
# 1. Compile with the aic-profiling flags
# 2. Run with the aic-profiling flags
#
# In this example JSON trace files are generated in the profiling output directory ./optraces. The trace files can be viewed with the Chrome/Chromium trace browser chrome://tracing.

# %%
# !rm -rf compiled_fp16
# !/opt/qti-aic/exec/qaic-exec -v -aic-hw  -convert-to-fp16 \
-mos=1 -ols=1 -aic-num-cores=2 \
-m=bert_base_cased_onnx/model_fix_outofrange_fp16.onnx \
-onnx-define-symbol=sequence_length,128 -onnx-define-symbol=batch_size,8 \
-aic-perf-metrics -multicast-weights -stats-batchsize=8 -aic-binary-dir=./compiled_fp16 \
-aic-hw-version=2.0 -compile-only \
-aic-profiling-type=stats -aic-profiling-type=trace -aic-profiling-type=latency
# Out:
# Reading ONNX Model from bert_base_cased_onnx/model_fix_outofrange_fp16.onnx
# Compile started ...............
# Compiling model with FP16 precision.
# AIC WARNING: MAC estimate does not yet handle all operations
# Original MAC estimate: 18446744060020916224
# Original Graph operation size histogram:
# output elts    op count (cumulative)
#        1024                  13   2%
#        2048                  15   2%
#      786432                 333  64%
#     1572864                 420  81%
#     3145728                 516 100%
# preD32 constants size: 342228040 B
# AIC HMX MAC estimate:  18446744060044509184
# AIC non-HMX MAC estimate:  0
# d32 constants size: 215076032 B
# final constants size: 215076032 B
# Using VTCM alg: NOT fatness reduced first fit reset
# MulticastTableSize: 6
# VTCM0Size:   8323072 B
# VTCM1Size:   8323072 B
# VTCMMaxSize: 8323072 B
# StaticSharedDDRSize: 	      886016 B
# DynamicSharedDDRSize: 	           0 B
# StaticConstantsSize: 	   215076864 B
# DynamicConstantsSize: 	           0 B
# Constants size: 215076864 (bytes)
# QAicGraph
# Compiler estimated memory traffic:
# Port info:
#  port01: host input
#  port02: host outut
#    host: DDR traffic  read:        864 KB (first-inf        864 KB)
#              constant only:          0 KB (first-inf          0 KB)
#  port02: DDR traffic  read:        864 KB
#     c00: DDR traffic  read:      83957 KB (first-inf      83957 KB)
#              constant only:      83957 KB (first-inf      83957 KB)
#     c01: DDR traffic  read:      84120 KB (first-inf      84120 KB)
#              constant only:      84120 KB (first-inf      84120 KB)
#    host: DDR traffic write:          0 KB
#     c00: DDR traffic write:        864 KB
#     c01: DDR traffic write:        864 KB
#    host: MC  traffic  read:          4 KB
#  port02: MC  traffic  read:          4 KB
#     c00: MC  traffic  read:          0 KB
#     c01: MC  traffic  read:          0 KB
#    host: MC  traffic write:         12 KB
#  port01: MC  traffic write:         12 KB
#     c00: MC  traffic write:      83190 KB
#     c00:     constant only:        244 KB
#     c01: MC  traffic write:      83352 KB
#     c01:     constant only:        408 KB
#   total: DDR traffic  read:     168941 KB (first-inf     168941 KB)
#              constant only:     168077 KB (first-inf     168077 KB)
#   total: DDR traffic write:       1729 KB
#   total: MC  traffic  read:          4 KB
#   total: MC  traffic write:     166554 KB
#   total:     constant only:        652 KB
#   c00 barriers:          3
#   c01 barriers:          3
# Number of specialized kernels: 50
# Number of shared specialized kernels: 10476
# ELF sections size: 516664 (bytes)
# Generated binary is present at ./compiled_fp16

# %% [markdown]
# **-aic-perf-metrics** dumps the compiler estimate of the usage of DDR vs VTCM (Vector Tightly Coupled Memory). The compiler tries to place the intermediate layer outputs and weights in VTCM. 'Constant only' refer to the weights of the network. The difference in 'DDR traffic in' and 'constant only' provides any spilover of intermediate outputs to DDR which impacts performance.

# %%
# !mkdir bert_base_cased_stats
# !/opt/qti-aic/exec/qaic-runner --test-data ./compiled_fp16  -d 0 -S 1 -a 7 \
--aic-profiling-type latency --aic-profiling-out-dir ./bert_base_cased_stats \
--aic-profiling-type stats --aic-profiling-type trace \
--aic-profiling-start-iter 100 --aic-profiling-num-samples 1 --time 20

#Note: The throughput will drop significantly with --aic-profiling-type ascii --aic-profiling-type trace flags
# Out:
# Writing file:./bert_base_cased_stats/aic-profiling-program-0-trace.json
# Deleting previous file: ./bert_base_cased_stats/aic-profiling-program-0-trace.json
# Writing file:./bert_base_cased_stats/aic-profiling-program-0-trace.json
# Deleting previous file: ./bert_base_cased_stats/aic-profiling-program-0-trace.json
# Writing file:./bert_base_cased_stats/aic-profiling-program-0-trace.json
# Deleting previous file: ./bert_base_cased_stats/aic-profiling-program-0-trace.json
# Writing file:./bert_base_cased_stats/aic-profiling-program-0-trace.json
# Deleting previous file: ./bert_base_cased_stats/aic-profiling-program-0-trace.json
# Writing file:./bert_base_cased_stats/aic-profiling-program-0-trace.json
# Deleting previous file: ./bert_base_cased_stats/aic-profiling-program-0-trace.json
# Writing file:./bert_base_cased_stats/aic-profiling-program-0-trace.json
# Deleting previous file: ./bert_base_cased_stats/aic-profiling-program-0-trace.json
# Writing file:./bert_base_cased_stats/aic-profiling-program-0-trace.json
# Writing file:./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Deleting previous file: ./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Writing file:./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Deleting previous file: ./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Writing file:./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Deleting previous file: ./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Writing file:./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Deleting previous file: ./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Writing file:./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Deleting previous file: ./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Writing file:./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Deleting previous file: ./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Writing file:./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Writing file:./bert_base_cased_stats/aic-profiling-program-0-activation-3-inf-100.txt
# Writing file:./bert_base_cased_stats/aic-profiling-program-0-activation-2-inf-100.txt
# Writing file:./bert_base_cased_stats/aic-profiling-program-0-activation-1-inf-100.txt
# Writing file:./bert_base_cased_stats/aic-profiling-program-0-activation-4-inf-100.txt
# Writing file:./bert_base_cased_stats/aic-profiling-program-0-activation-5-inf-100.txt
# Writing file:./bert_base_cased_stats/aic-profiling-program-0-activation-6-inf-100.txt
# Writing file:./bert_base_cased_stats/aic-profiling-program-0-activation-0-inf-100.txt
#  ---- Stats ----
# InferenceCnt 4816 TotalDuration 20022021us BatchSize 8 Inf/Sec 1924.281
# Device Performance:
# Metric,          Avg,           Min,           Max,           Std
# ExecTimeUs,      22861.091,     22236.458,     31251.875,     513.795
# InputWaitTimeUs, 6980.003,      617.552,       3290982.552,   134573.376
# OutputWaitTimeUs,0.138,         0.104,         2.083,         0.115

# %% [markdown]
# ## Summary View
# A summary text file is created per instance (running on 1 or more NSP cores) showing distribution of the load on every NSP. There are 4 HVX(Vector Unit), 1 HMX(Matrix Unit) and 1 DMA engine per NSP. This stats shows % utilization of every engine with total number of cycles required for computation. It also has operator wise break down of cycles consumed.

# %%
# !cat bert_base_cased_stats/aic-profiling-program-0-activation-0-inf-100.txt
# Out:
# core  ucycles  ucycles(%)     pcycles  pcycles(%)  count      out KB  ucycles/KB  pcycles/KB  stddev(pc/KB)  opdetails
# c0     424682      95.50%         N/A         N/A    759         N/A         N/A         N/A            N/A  sync DMAIssue
# c0     244552      55.00%    15612581      54.67%   1081   525124.00        0.47       29.73          20.98  aicconvolutiond32 HMX TCM (float16, i8, index32)
# c0     186007      41.83%         N/A         N/A    906         N/A         N/A         N/A            N/A  sync HMX
# c0     164066      36.90%         N/A         N/A    646         N/A         N/A         N/A            N/A  sync HVX
# c0      70129      15.77%     4532059      15.87%     24    18432.00        3.80      245.88          11.79  aicsoftmax HVX TCM (float16, i8, index64)
# c0      67009      15.07%       97200       0.34%    413    83189.12        0.81        1.17         104.81  aiccopytovtcm DMAIssue DDR
# c0      62830      14.13%     3950024      13.83%     72    36864.00        1.70      107.15          18.85  elementerf  HVX TCM (float16)
# c0      32866       7.39%     2126216       7.44%     48    36864.00        0.89       57.68          60.28  aictranspose HVX TCM (float16)
# c0      22368       5.03%     1451308       5.08%     25    19200.00        1.17       75.59           0.43  aiclayernormd32 HVX TCM (float16)
# c0      17012       3.83%     1083762       3.79%     49    37632.00        0.45       28.80           6.75  aicconverttod32 HVX TCM (float16, i8)
# c0      16781       3.77%      108781       0.38%    413    83188.12        0.20        1.31         104.57  aicmulticastvtcm DMAIssue TCM
# c0      15492       3.48%         N/A         N/A    653         N/A         N/A         N/A            N/A  barrier HVX
# c0      13929       3.13%      884238       3.10%    145    73730.00        0.19       11.99           6.23  aicmulsplat  HVX TCM (float16)
# c0      13519       3.04%      873523       3.06%     62    55299.00        0.24       15.80        1192.64  aicconvertfromd32 HVX TCM (float16)
# c0      13396       3.01%         N/A         N/A    690         N/A         N/A         N/A            N/A  barrier DMAIssue
# c0      11244       2.53%      727544       2.55%     24    18432.00        0.61       39.47           1.82  aicconvertweightstod32 HVX TCM (float16)
# c0      10606       2.39%      672426       2.35%     72    36864.00        0.29       18.24           3.89  elementmul  HVX TCM (float16)
# c0       9593       2.16%         N/A         N/A    811         N/A         N/A         N/A            N/A  barrier HMX
# c0       9375       2.11%      606547       2.12%     13    19200.00        0.49       31.59           5.37  aicbroadcastadd HVX TCM (float16)
# c0       7134       1.60%      452813       1.59%     72    36864.00        0.19       12.28           3.36  aicaddsplat  HVX TCM (float16)
# c0       3758       0.85%      243902       0.85%     25    19200.00        0.20       12.70           1.81  elementadd  HVX TCM (float16)
# c0       2886       0.65%        3385       0.01%     13     9984.00        0.29        0.34           0.03  aiccopysamevtcm HVX TCM
# c0       2419       0.54%       22122       0.08%     72    27648.00        0.09        0.80           0.54  aiccopysamevtcm2d HMX TCM
# c0        917       0.21%       57723       0.20%      1      768.00        1.19       75.16           0.00  aicgather HVX DDR (float16, ui8, index32)
# c0        354       0.08%       22294       0.08%      1      768.00        0.46       29.03           0.00  aicgather HVX TCM (float16, ui8, index32)
# c0        353       0.08%       22229       0.08%      1        2.00      176.50    11114.50           0.00  convertto HVX TCM (float16, index32)
# c0         86       0.02%         237       0.00%      1        1.00       86.00      237.00           0.00  aiccopysamevtcm2d HVX TCM
# c0         85       0.02%        5629       0.02%      1      864.63        0.10        6.51           0.00  aicendcyclestats DMAIssue DDR (i8)
# c0         77       0.02%        5075       0.02%      1      864.63        0.09        5.87           0.00  aicendcyclestats HMX DDR (i8)
# c0         77       0.02%        5065       0.02%      1      864.63        0.09        5.86           0.00  aicendcyclestats HVX DDR (i8)
# c0         21       0.00%         540       0.00%      2        2.00       10.50      270.00           9.00  aicmulticastvtcm HVX TCM
# c0          5       0.00%         320       0.00%      1       12.00        0.42       26.67           0.00  aicinputsemaphoreinc HVX TCM (i8, index32)
# c0          1       0.00%         109       0.00%      1        2.00        0.50       54.50           0.00  elementsub  HVX TCM (float16)
#
# c0 total:          444672 ucycles        28559104 pcycles (thread max)
# c0    t0 HVX               444602 ucycles [9803252406782, 9803252851384]        28554461 pcycles  59.72% utilization
# c0    t1 HVX               444602 ucycles [9803252406783, 9803252851385]        28554459 pcycles  61.41% utilization
# c0    t2 HVX               444603 ucycles [9803252406782, 9803252851385]        28554512 pcycles  61.46% utilization
# c0    t3 HVX               444602 ucycles [9803252406783, 9803252851385]        28554454 pcycles  59.50% utilization
# c0    t4 HMX               444603 ucycles [9803252406782, 9803252851385]        28554502 pcycles  54.77% utilization
# c0    t5 DMAIssue          444672 ucycles [9803252406783, 9803252851455]        28559104 pcycles   0.74% utilization
#
#
# c00t0 batch ucycles:           444602 [9803252406782,9803252851384]    pcycles:        28554461
# c00t1 batch ucycles:           444602 [9803252406783,9803252851385]    pcycles:        28554459
# c00t2 batch ucycles:           444603 [9803252406782,9803252851385]    pcycles:        28554512
# c00t3 batch ucycles:           444602 [9803252406783,9803252851385]    pcycles:        28554454
# c00t4 batch ucycles:           444603 [9803252406782,9803252851385]    pcycles:        28554502
# c00t5 batch ucycles:           444672 [9803252406783,9803252851455]    pcycles:        28559104
# c0: Total inference pcycle is 28559169
# c0: Effective frequency is 1233.12MHz
# c00t0p100 Host_IO_Port ucycles:            30711
# c00t1p100 Host_IO_Port ucycles:                0
# c00t2p100 Host_IO_Port ucycles:                0
# c00t3p100 Host_IO_Port ucycles:                0
# c00t4p100 Host_IO_Port ucycles:                0
# c00t5p100 Host_IO_Port ucycles:                0
# c00t0p101 Host_IO_Port ucycles:                2
# c00t1p101 Host_IO_Port ucycles:                2
# c00t2p101 Host_IO_Port ucycles:                1
# c00t3p101 Host_IO_Port ucycles:                2
# c00t4p101 Host_IO_Port ucycles:                1
# c00t5p101 Host_IO_Port ucycles:                1
# c00t0 activate ucycles:              4386
# c00t1 activate ucycles:              4339
# c00t2 activate ucycles:              4246
# c00t3 activate ucycles:              4161
# c00t4 activate ucycles:              4067
# c00t5 activate ucycles:              1519
#
# core  ucycles  ucycles(%)     pcycles  pcycles(%)  count      out KB  ucycles/KB  pcycles/KB  stddev(pc/KB)  opdetails
# c1     424668      95.56%         N/A         N/A    758         N/A         N/A         N/A            N/A  sync DMAIssue
# c1     240061      54.02%    15560590      54.04%   1081   525124.00        0.46       29.63          20.22  aicconvolutiond32 HMX TCM (float16, i8, index32)
# c1     190349      42.83%         N/A         N/A    926         N/A         N/A         N/A            N/A  sync HMX
# c1     156695      35.26%         N/A         N/A    638         N/A         N/A         N/A            N/A  sync HVX
# c1      73500      16.54%     4756082      16.52%     24    18432.00        3.99      258.03           7.45  aicsoftmax HVX TCM (float16, i8, index64)
# c1      66800      15.03%     4326084      15.02%     72    36864.00        1.81      117.35          10.64  elementerf  HVX TCM (float16)
# c1      65611      14.76%       94643       0.33%    411    83352.06        0.79        1.14         284.41  aiccopytovtcm DMAIssue DDR
# c1      32782       7.38%     2120663       7.37%     48    36864.00        0.89       57.53          58.26  aictranspose HVX TCM (float16)
# c1      22389       5.04%     1451328       5.04%     25    19200.00        1.17       75.59           0.41  aiclayernormd32 HVX TCM (float16)
# c1      18470       4.16%         N/A         N/A    649         N/A         N/A         N/A            N/A  barrier HVX
# c1      18006       4.05%     1163795       4.04%     49    37632.00        0.48       30.93           8.50  aicconverttod32 HVX TCM (float16, i8)
# c1      16153       3.63%      111736       0.39%    411    83352.06        0.19        1.34         360.63  aicmulticastvtcm DMAIssue TCM
# c1      14038       3.16%      910583       3.16%    144    73728.00        0.19       12.35           5.36  aicmulsplat  HVX TCM (float16)
# c1      13369       3.01%      865455       3.01%     62    55299.00        0.24       15.65        1083.27  aicconvertfromd32 HVX TCM (float16)
# c1      13285       2.99%         N/A         N/A    714         N/A         N/A         N/A            N/A  barrier DMAIssue
# c1      11220       2.52%      726179       2.52%     24    18432.00        0.61       39.40           1.87  aicconvertweightstod32 HVX TCM (float16)
# c1      10281       2.31%      665072       2.31%     13    19200.00        0.54       34.64           6.35  aicbroadcastadd HVX TCM (float16)
# c1       9650       2.17%      626856       2.18%     72    36864.00        0.26       17.00           4.43  elementmul  HVX TCM (float16)
# c1       9497       2.14%         N/A         N/A    809         N/A         N/A         N/A            N/A  barrier HMX
# c1       6362       1.43%      412148       1.43%     72    36864.00        0.17       11.18           2.87  aicaddsplat  HVX TCM (float16)
# c1       3762       0.85%      243650       0.85%     25    19200.00        0.20       12.69           1.86  elementadd  HVX TCM (float16)
# c1       2883       0.65%        3701       0.01%     14     9985.00        0.29        0.37          67.13  aiccopysamevtcm HVX TCM
# c1       2368       0.53%       21045       0.07%     72    27648.00        0.09        0.76           0.53  aiccopysamevtcm2d HMX TCM
# c1        935       0.21%       58961       0.20%      1      768.00        1.22       76.77           0.00  aicgather HVX DDR (float16, ui8, index32)
# c1        351       0.08%       22078       0.08%      1      768.00        0.46       28.75           0.00  aicgather HVX TCM (float16, ui8, index32)
# c1        152       0.03%         251       0.00%      1        1.00      152.00      251.00           0.00  aiccopysamevtcm2d HVX TCM
# c1         99       0.02%        6534       0.02%      1      864.63        0.11        7.56           0.00  aicendcyclestats HMX DDR (i8)
# c1         83       0.02%        5432       0.02%      1      864.63        0.10        6.28           0.00  aicendcyclestats HVX DDR (i8)
# c1         52       0.01%        3465       0.01%      1      864.63        0.06        4.01           0.00  aicendcyclestats DMAIssue DDR (i8)
# c1          4       0.00%         229       0.00%      1        8.00        0.50       28.62           0.00  aicinputsemaphoreinc HVX TCM (i8)
# c1          2       0.00%        1579       0.01%      1        1.00        2.00     1579.00           0.00  aiccopysamevtcm DMAIssue TCM
#
# c1 total:          444413 ucycles        28793610 pcycles (thread max)
# c1    t0 HVX               444308 ucycles [9803252406778, 9803252851086]        28786630 pcycles  61.34% utilization
# c1    t1 HVX               444308 ucycles [9803252406778, 9803252851086]        28786669 pcycles  62.55% utilization
# c1    t2 HVX               444307 ucycles [9803252406779, 9803252851086]        28786619 pcycles  62.26% utilization
# c1    t3 HVX               444307 ucycles [9803252406779, 9803252851086]        28786657 pcycles  61.59% utilization
# c1    t4 HMX               444308 ucycles [9803252406778, 9803252851086]        28786739 pcycles  54.15% utilization
# c1    t5 DMAIssue          444413 ucycles [9803252406779, 9803252851192]        28793610 pcycles   0.73% utilization
#
#
# c01t0 batch ucycles:           444308 [9803252406778,9803252851086]    pcycles:        28786630
# c01t1 batch ucycles:           444308 [9803252406778,9803252851086]    pcycles:        28786669
# c01t2 batch ucycles:           444307 [9803252406779,9803252851086]    pcycles:        28786619
# c01t3 batch ucycles:           444307 [9803252406779,9803252851086]    pcycles:        28786657
# c01t4 batch ucycles:           444308 [9803252406778,9803252851086]    pcycles:        28786739
# c01t5 batch ucycles:           444413 [9803252406779,9803252851192]    pcycles:        28793610
# c1: Total inference pcycle is 28793705
# c1: Effective frequency is 1243.97MHz
# c01t0p100 Host_IO_Port ucycles:                0
# c01t1p100 Host_IO_Port ucycles:                0
# c01t2p100 Host_IO_Port ucycles:                0
# c01t3p100 Host_IO_Port ucycles:                0
# c01t4p100 Host_IO_Port ucycles:            30698
# c01t5p100 Host_IO_Port ucycles:                0
# c01t0p101 Host_IO_Port ucycles:                1
# c01t1p101 Host_IO_Port ucycles:                0
# c01t2p101 Host_IO_Port ucycles:                1
# c01t3p101 Host_IO_Port ucycles:                1
# c01t4p101 Host_IO_Port ucycles:                0
# c01t5p101 Host_IO_Port ucycles:                2
# c01t0 activate ucycles:              4051
# c01t1 activate ucycles:              4007
# c01t2 activate ucycles:              3924
# c01t3 activate ucycles:              3836
# c01t4 activate ucycles:              3739
# c01t5 activate ucycles:              1521
# total batch ucycles:           444677 [9803252406778, 9803252851455]
# [QAicGraph] Device instance batch/s: (1/0.0231603): 43.1774
# [QAicGraph] Device instance inf/s: (8/0.0231603): 345.419
# max input wait ucycles:             30711
# max output wait ucycles:                2

# %% [markdown]
# ## Detailed Timeline View
# JSON files hold the detailed timeline view of the inference executed on device.
# Open chrome://tracing in Chrome/Chromium and click the Load button to open and view one of the JSON files. Use the toolbar to select, pan and zoom the timelines.
#
# **Reading trace timeline** <br>
# The trace timeline is divided into HOST_PROC and Process 0 .. N sections.
#
# <div>
# <img src="images/opstats_decoder.png" width="500"/>
# </div>
#
# **Viewing Operators** <br>
# Zoom in to see individual operations. Here's an example showing convolution and softmax operations.
#
# <div>
# <img src="images/opstats_example.png" width="1000"/>
# </div>
#
# **Viewing Operator details** <br>
# Click on an operator to see more details. Here are details of one of the softmax operations.
#
# <div>
# <img src="images/operator_details.png" width="1000"/>
# </div>

# %% [markdown]
# # <span style='color:Blue'>4. System Level Profiling </span>
#
# System level profiling includes the breakdown of the inference time between Application, linux runtime , kernel mode driver and hardware processing.
#
# qaic-runner tools can help with system level profiling. The following flags are required during inference.
#
# **qaic-runner** <br>
# aic-profiling-type : latency <br>
# aic-profiling-out-dir : output directory for latency capture (needs to exist before this command is run) <br>
# aic-profiling-start-iter : Set this value high enough to start capturing samples after device warmup (~250mS) <br>
# aic-profiling-num-samples : # of samples to be captured. Can be set greater than # of inferences <br><br>
#
# <div>
# <img src="images/Latency.png" width="1000"/>
# </div>

# %%
# !/opt/qti-aic/exec/qaic-runner --test-data ./compiled_fp16  -d 0 -S 1 -a 7 \
--aic-profiling-type latency --aic-profiling-out-dir ./bert_base_cased_stats \
--aic-profiling-start-iter 100 --aic-profiling-num-samples 99999 --time 20
# Out:
#  ---- Stats ----
# InferenceCnt 5787 TotalDuration 20018960us BatchSize 8 Inf/Sec 2312.608
# Device Performance:
# Metric,          Avg,           Min,           Max,           Std
# ExecTimeUs,      22777.262,     22210.208,     25809.896,     374.926
# InputWaitTimeUs, 1403.480,      634.427,       2226.094,      233.809
# OutputWaitTimeUs,0.124,         0.104,         2.240,         0.090
#
# Deleting previous file: ./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Writing file:./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Deleting previous file: ./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Writing file:./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Deleting previous file: ./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Writing file:./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Deleting previous file: ./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Writing file:./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Deleting previous file: ./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Writing file:./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Deleting previous file: ./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Writing file:./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Deleting previous file: ./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Writing file:./bert_base_cased_stats/aic-profiling-program-0-latency.txt

# %%
# !python3 latency_stats_python3.py ./bert_base_cased_stats/aic-profiling-program-0-latency.txt
# Out:
# All activations combined:
#                           mean         min         50%         75%         90%         95%         99%         max
# devInfPerSec        347.295312  309.959000  350.840500  353.190250  354.376700  354.804700  355.412240  355.981000
# devExec              23.051370   22.473125   22.802370   23.164336   23.987068   24.345632   25.392607   25.809896
# devInWaitTime         1.385587    0.721927    1.400572    1.520768    1.661437    1.742192    1.920286    2.226094
# devOutWaitTime        0.000141    0.000104    0.000104    0.000104    0.000156    0.000365    0.000711    0.002083
# hostRoundTrip        23.372801   22.652000   23.126000   23.505500   24.291600   24.672150   25.697940   26.089000
# enqTime               0.006761    0.003787    0.006246    0.006934    0.007816    0.011465    0.019582    0.029266
# preProcTime           0.007632    0.004348    0.006613    0.007150    0.011401    0.016421    0.018368    0.029383
# submitTime            0.001556    0.000867    0.001410    0.001489    0.001636    0.002373    0.003220    0.018888
# execTotal            23.442736   22.735984   23.199531   23.567861   24.368197   24.778517   25.779636   26.183651
# exectoVc              0.004872    0.003000    0.005000    0.005000    0.006000    0.006000    0.014150    0.023000
# execToComplete       23.367929   22.648000   23.121500   23.501500   24.286900   24.667150   25.693110   26.084000
# postProc              0.182493    0.116404    0.183056    0.198956    0.211585    0.224873    0.252200    0.295622
# totalRoundtripTime   23.693604   22.946043   23.453992   23.839635   24.596035   25.033388   26.064658   26.408334
# totalRoundtripTime: percentile(mean) = 23.694 ms
