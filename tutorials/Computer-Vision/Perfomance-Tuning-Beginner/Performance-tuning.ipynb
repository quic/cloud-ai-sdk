# %% [markdown]
# Copyright (c) 2025 Qualcomm Innovation Center, Inc. All rights reserved.<br>
# SPDX-License-Identifier: BSD-3-Clause-Clear

# %% [markdown]
# **Takeaways:** Users will learn how to tune the Resnet50 model for best throughput and latency
#
# **Before you start:**
# - There are some commands (folder locations etc) that will need to be updated in this notebook based on the platform and installation location. Some commands might need sudo prefix to run properly.
# - The terms 'model' and 'network' are used interchangeably in this notebook.
# - The terms 'NSP' and 'AI compute core" are used interchangeably in this notebook.
#
# **Last Verified Qualcomm Cloud AI Platform SDK and Apps SDK Version:** Platform SDK 1.19.2 and Apps SDK 1.19.2

# %% [markdown]
# # <span style='color:Blue'> Performance Tuning on Cloud AI </span>
#
# ##  Pre-requisite reading
# New users on Cloud AI platforms are expected to go over the Cloud AI SoC architecture and the key compile/runtime parameters that determine performance. This is discussed in the Tune Performance section in the Inference workflow documentation.
#
#
# ## Introduction
# This notebook is for beginners and will take the user through the workflow to achieve best throughput and latency on Cloud AI platforms for the Resnet50 model.
#
# Here is the workflow that will be demonstated in this notebook.
#
# 1. **Install required packages**: Begin by installing all the required packages
# 2. **Import the model**: Download the Resnet50 model in ONNX.
# 2. **Device Health Check**: Query the device health using qaic-util tool.
# 2. **Identify best throughput configuration**: Go over the Model Configurator tool to identify best throughput
# 3. **Identity least latency configuration**: Go over the key parameters to tweak for least latency

# %% [markdown]
# # <span style='color:Blue'> 1. Install required packages </span>
#
# We will install the required Python packages

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: onnx==1.12.0 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from -r requirements.txt (line 1)) (1.12.0)
# Requirement already satisfied: optimum in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from -r requirements.txt (line 2)) (1.23.3)
# Requirement already satisfied: numpy==1.23.4 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from -r requirements.txt (line 3)) (1.23.4)
# Requirement already satisfied: onnxruntime in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from -r requirements.txt (line 4)) (1.15.0)
# Requirement already satisfied: torch==1.13.0 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from -r requirements.txt (line 5)) (1.13.0+cpu)
# Requirement already satisfied: pillow==8.3.2 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from -r requirements.txt (line 6)) (8.3.2)
# Requirement already satisfied: opencv-python in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from -r requirements.txt (line 7)) (4.11.0.86)
# Requirement already satisfied: paramiko in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from -r requirements.txt (line 8)) (3.5.1)
# Requirement already satisfied: jsonschema in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from -r requirements.txt (line 9)) (4.23.0)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from onnx==1.12.0->-r requirements.txt (line 1)) (4.13.2)
# Requirement already satisfied: protobuf<=3.20.1,>=3.12.2 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from onnx==1.12.0->-r requirements.txt (line 1)) (3.20.1)
# Requirement already satisfied: transformers>=4.29 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from optimum->-r requirements.txt (line 2)) (4.29.2)
# Requirement already satisfied: packaging in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from optimum->-r requirements.txt (line 2)) (25.0)
# Requirement already satisfied: coloredlogs in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from optimum->-r requirements.txt (line 2)) (15.0.1)
# Requirement already satisfied: huggingface-hub>=0.8.0 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from optimum->-r requirements.txt (line 2)) (0.30.2)
# Requirement already satisfied: sympy in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from optimum->-r requirements.txt (line 2)) (1.13.3)
# Requirement already satisfied: datasets in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from optimum->-r requirements.txt (line 2)) (3.1.0)
# Requirement already satisfied: flatbuffers in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from onnxruntime->-r requirements.txt (line 4)) (25.2.10)
# Requirement already satisfied: cryptography>=3.3 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from paramiko->-r requirements.txt (line 8)) (44.0.2)
# Requirement already satisfied: pynacl>=1.5 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from paramiko->-r requirements.txt (line 8)) (1.5.0)
# Requirement already satisfied: bcrypt>=3.2 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from paramiko->-r requirements.txt (line 8)) (4.3.0)
# Requirement already satisfied: importlib-resources>=1.4.0; python_version < "3.9" in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from jsonschema->-r requirements.txt (line 9)) (6.4.5)
# Requirement already satisfied: attrs>=22.2.0 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from jsonschema->-r requirements.txt (line 9)) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from jsonschema->-r requirements.txt (line 9)) (2023.12.1)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10; python_version < "3.9" in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from jsonschema->-r requirements.txt (line 9)) (1.3.10)
# Requirement already satisfied: referencing>=0.28.4 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from jsonschema->-r requirements.txt (line 9)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from jsonschema->-r requirements.txt (line 9)) (0.20.1)
# Requirement already satisfied: filelock in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from transformers>=4.29->optimum->-r requirements.txt (line 2)) (3.16.1)
# Requirement already satisfied: regex!=2019.12.17 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from transformers>=4.29->optimum->-r requirements.txt (line 2)) (2024.11.6)
# Requirement already satisfied: tqdm>=4.27 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from transformers>=4.29->optimum->-r requirements.txt (line 2)) (4.67.1)
# Requirement already satisfied: pyyaml>=5.1 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from transformers>=4.29->optimum->-r requirements.txt (line 2)) (6.0.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from transformers>=4.29->optimum->-r requirements.txt (line 2)) (0.13.3)
# Requirement already satisfied: requests in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from transformers>=4.29->optimum->-r requirements.txt (line 2)) (2.32.3)
# Requirement already satisfied: humanfriendly>=9.1 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from coloredlogs->optimum->-r requirements.txt (line 2)) (10.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from huggingface-hub>=0.8.0->optimum->-r requirements.txt (line 2)) (2024.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from sympy->optimum->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: pandas in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from datasets->optimum->-r requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: aiohttp in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from datasets->optimum->-r requirements.txt (line 2)) (3.10.11)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from datasets->optimum->-r requirements.txt (line 2)) (0.3.8)
# Requirement already satisfied: xxhash in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from datasets->optimum->-r requirements.txt (line 2)) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from datasets->optimum->-r requirements.txt (line 2)) (0.70.16)
# Requirement already satisfied: pyarrow>=15.0.0 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from datasets->optimum->-r requirements.txt (line 2)) (17.0.0)
# Requirement already satisfied: cffi>=1.12; platform_python_implementation != "PyPy" in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from cryptography>=3.3->paramiko->-r requirements.txt (line 8)) (1.17.1)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from importlib-resources>=1.4.0; python_version < "3.9"->jsonschema->-r requirements.txt (line 9)) (3.20.2)
# Requirement already satisfied: certifi>=2017.4.17 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from requests->transformers>=4.29->optimum->-r requirements.txt (line 2)) (2025.4.26)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from requests->transformers>=4.29->optimum->-r requirements.txt (line 2)) (1.26.6)
# Requirement already satisfied: idna<4,>=2.5 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from requests->transformers>=4.29->optimum->-r requirements.txt (line 2)) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from requests->transformers>=4.29->optimum->-r requirements.txt (line 2)) (3.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from pandas->datasets->optimum->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.1 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from pandas->datasets->optimum->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from pandas->datasets->optimum->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from aiohttp->datasets->optimum->-r requirements.txt (line 2)) (6.1.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from aiohttp->datasets->optimum->-r requirements.txt (line 2)) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from aiohttp->datasets->optimum->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0; python_version < "3.11" in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from aiohttp->datasets->optimum->-r requirements.txt (line 2)) (5.0.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from aiohttp->datasets->optimum->-r requirements.txt (line 2)) (1.5.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from aiohttp->datasets->optimum->-r requirements.txt (line 2)) (1.15.2)
# Requirement already satisfied: pycparser in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from cffi>=1.12; platform_python_implementation != "PyPy"->cryptography>=3.3->paramiko->-r requirements.txt (line 8)) (2.22)
# Requirement already satisfied: six>=1.5 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas->datasets->optimum->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: propcache>=0.2.0 in /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets->optimum->-r requirements.txt (line 2)) (0.2.0)
#   Preparing metadata (pyproject.toml) ... done
# ERROR: Cannot install -r requirements.txt (line 1), -r requirements.txt (line 4), numpy==1.23.4 and onnxruntime==1.15.1 because these package versions have conflicting dependencies.
#
# The conflict is caused by:
#     The user requested numpy==1.23.4
#     onnx 1.12.0 depends on numpy>=1.16.6
#     onnxruntime 1.15.1 depends on numpy>=1.24.2
#     The user requested numpy==1.23.4
#     onnx 1.12.0 depends on numpy>=1.16.6
#     onnxruntime 1.15.0 depends on numpy>=1.24.2
#
# To fix this you could try to:
# 1. loosen the range of package versions you've specified
# 2. remove package versions to allow pip attempt to solve the dependency conflict
#
# ERROR: ResolutionImpossible: for help visit https://pip.pypa.io/en/latest/topics/dependency-resolution/#dealing-with-dependency-conflicts
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# # <span style='color:Blue'>2. Download the model </span>
#
# Download the pretrained Resnet50 model.

# %%
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"
# !optimum-cli export onnx --model 'microsoft/resnet-50' resnet-50_onnx/ --opset 11 --task image-classification --width 224 --height 224 --num_channels 3
# Out:
# /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages/huggingface_hub/file_download.py:896: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json: 100%|██████████████████████████| 69.6k/69.6k [00:00<00:00, 994kB/s]
# pytorch_model.bin: 100%|██████████████████████| 103M/103M [00:01<00:00, 100MB/s]
# preprocessor_config.json: 100%|█████████████████| 266/266 [00:00<00:00, 121kB/s]
# Could not find image processor class in the image processor config or the model config. Loading based on pattern matching with the model's feature extractor configuration.
# /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages/transformers/models/convnext/feature_extraction_convnext.py:28: FutureWarning: The class ConvNextFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use ConvNextImageProcessor instead.
#   warnings.warn(
# Could not find image processor class in the image processor config or the model config. Loading based on pattern matching with the model's feature extractor configuration.
# /local/mnt/workspace/rchittet/cv/cloud-ai-sdk/models/vision/detection/det_env/lib/python3.8/site-packages/transformers/models/resnet/modeling_resnet.py:95: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if num_channels != self.num_channels:
# Weight deduplication check in the ONNX export requires accelerate. Please install accelerate to run it.

# %% [markdown]
# # <span style='color:Blue'> 3. Check device health </span>
#
# 'qaic-util' tool can be used to query the health of all the Cloud AI cards in the server. (Ensure that the command is run with sudo or this jupyter notebook is run with --allow-root and sudo)
#
# "Status: Ready" indicates that the health of the cards is good.
# "Status: Error" indicates that the cards are not in good health and a system administrator needs to be contacted to rectify the issue.

# %%
# !/opt/qti-aic/tools/qaic-util -q | grep "Status"
# Out:
# 	Status:Ready
# 	Status:Ready
# 	Status:Ready
# 	Status:Ready

# %% [markdown]
# # <span style='color:Blue'> 4. Identify the best throughput configuration </span>
#
# Model Configurator is a python script that is used to find the optimal configuration of batch size, cores etc for a given model for the throughput (Inf/s). The input to model configurator is the model and a search space that the tool iterates over.
#
# 1. Use the optimal config (model configurator output) as an indicator of the best compile flags.
# 2. Compile with qaic-exec and run with qaic-runner using optimal config from step 1 to validate the performance.
#
# Additional details on the Parameters- https://quic.github.io/cloud-ai-sdk-pages/latest/Getting-Started/Inference-Workflow/model-compilation/Tune-performance/
#
# Additional Documentation on Model Configurator tool here- https://docs.qualcomm.com/bundle/publicresource/topics/80-PT790-993B/network-perform-tuning.html#network-perform-tuning_qaic-model-configurator
#
# Key compile optimization flags are
# - **aic-num-cores** : # of AI compute cores (aka NSP) used to compile the model
# - **bs** : batch size
# - **mos** : Maximum output splitting, denotes the no of AI compute cores across which an output channel (and associated weights) is split.
# - **ols** : Overlap splitting, enabled output splitting to improve core level parallelism, eg tensor and vector unit
#
# Key runtime optimization flags are
# - **instance/activations** : No of instances of the compiled binary that can be run based on the # of AI compute cores on the card
# - **set-size** : denotes the number of inferences per instance that can be queued up on the host. Hides host side overhead by pipelining inferences. CV models typically can benefit from higher set-sizes for higher throughput (with increased latency).

# %% [markdown]
# ## Config Optimizer
# The optimized search is run on one or more searchable parameters (aic-num-cores, instances, batch-size etc). The search space is provided through a json configuration file.
# This table captures the key elements of the configuration file.
#
# | Key | Type | Description | Recommended value|
# | :- |:- | :- | :-|
# |"max_func_eval"|Integer|Maximun number of evaluations to do for each initial point. This number can be increased if successful convergence is not achieved|200|
# |"Objective"|String| Search objective. Options are "max-throughput" or "min-latency" | Choose "max-throughput" for maximum throughput or "min-latency" for minimum latency |
# |“params”|Json Object|Provide the search range for each of the parameters - cores, mos, ols, etc. through min, max values| See table below |
# “initial_values”|List of Json Objects|List of initial values for the search parameters. A fresh search is initiated from each of these points and the results returned. Initial Values must be picked from within the search range defined in “params”|	Provide multiple initial values as shown in the example json|
# |“static_params”|Json Object|Optional static values to be used for searchable parameters which have been excluded from the search space| |
#
#
# ### Parameter Range
#
#
# | Parameter|	Recommended Search Range|	Valid Range |	Comments|
# | :- | :- | :- | :-|
# |cores|	|	1-14(Standard Card), 1-16 (Pro/Ultra Card)| cores*instances should be less than or equal to the number of NSP's on the device 1-14(Standard Card), 1-16 (Pro/Ultra Card)|
# |instances|	|1-14(Standard Card), 1-16 (Pro/Ultra Card)| cores*instances should be less than or equal to the number of NSP's on the device 1-14(Standard Card), 1-16 (Pro/Ultra Card)
# |mos	|1-Number of NSP on device|	Number of NSP's on device||
# |ols	|1-8|	Integers>0|
# |batch-size (bs)|	1-16|	Integers>0|	Min, max values must be power of 2. The max value would depend on the model|

# %%
#Lets assume the max Number of NSP on the device is 14. 
# !cat resnet_base_dopt_throughput.json
# Out:
# {
#   "search-mode": "optimized",
#   "objective": "max-throughput",
#   "search-parameters": {
#     "cores": {
#       "min": 1,
#       "max": 14
#     },
#     "mos": {
#       "min": 1,
#       "max": 8
#     },
#     "ols": {
#       "min": 1,
#       "max": 8
#     },
#     "batch-size": {
#       "min": 1,
#       "max": 16
#     },
#     "instances": {
#       "min": 1,
#       "max": 14
#     },
#     "set-size": {
#       "min": 1,
#       "max": 10
#     }
#   },
#   "initial-values": [
#     {
#       "cores": 1,
#       "mos": 1,
#       "ols": 1,
#       "batch-size": 1,
#       "instances": 14,
#       "set-size": 1
#
#     },
#     {
#       "cores": 2,
#       "mos": 1,
#       "ols": 1,
#       "batch-size": 1,
#       "instances": 7,
#       "set-size": 1
#     },
#     {
#       "cores": 4,
#       "mos": 1,
#       "ols": 1,
#       "batch-size": 1,
#       "instances": 3,
#       "set-size": 1
#     },
#     {
#       "cores": 7,
#       "mos": 1,
#       "ols": 1,
#       "batch-size": 1,
#       "instances": 2,
#       "set-size": 1
#     },
#     {
#       "cores": 14,
#       "mos": 1,
#       "ols": 1,
#       "batch-size": 1,
#       "instances": 1,
#       "set-size": 1
#     }
#   ]
# }

# %%
# Dump the model inputs and outputs 

import onnx
model = onnx.load("resnet-50_onnx/model.onnx")
for _input in model.graph.input:
    print(_input)
for _output in model.graph.output:
    print(_output)
# Out:
# name: "pixel_values"
# type {
#   tensor_type {
#     elem_type: 1
#     shape {
#       dim {
#         dim_param: "batch_size"
#       }
#       dim {
#         dim_param: "num_channels"
#       }
#       dim {
#         dim_param: "height"
#       }
#       dim {
#         dim_param: "width"
#       }
#     }
#   }
# }
#
# name: "logits"
# type {
#   tensor_type {
#     elem_type: 1
#     shape {
#       dim {
#         dim_param: "batch_size"
#       }
#       dim {
#         dim_value: 1000
#       }
#     }
#   }
# }

# %%
# Run model_configurator tool to identify the best throughput configuration. 
# For CV networks, higher set sizes are preferred for higher throughput. Default set-size is 10. 
# !python3 /opt/qti-aic/scripts/qaic-model-configurator/model_configurator.py -model resnet-50_onnx/model.onnx \
-onnx-define-symbol-batch-size=batch_size \
-onnx-define-symbol=num_channels,3 -onnx-define-symbol=height,224  -onnx-define-symbol=width,224 \
-multicast-weights \
-config=resnet_base_dopt_throughput.json -max-parallel-compilations=16 -time=5 \
-convert-to-fp16 -device-id=0
# Out:
# 2025-04-29 01:39:21.809 - [INFO]: Starting /opt/qti-aic/scripts/qaic-model-configurator/model_configurator.py -model resnet-50_onnx/model.onnx -onnx-define-symbol-batch-size=batch_size -onnx-define-symbol=num_channels,3 -onnx-define-symbol=height,224 -onnx-define-symbol=width,224 -multicast-weights -config=resnet_base_dopt_throughput.json -max-parallel-compilations=16 -time=5 -convert-to-fp16 -device-id=0
# 2025-04-29 01:39:21.811 - [INFO]: Hostname: qrc706r11-282-07, Physical Cores: 48, Logical Cores: 48, Memory: 503.8 GB
# 2025-04-29 01:39:22.085 - [INFO]: Running optimized search
# 2025-04-29 01:39:22.102 - [INFO]: Running optimization algorithm from initial values: [(cores=1, mos=[1], ols=1, batchSize=1, instances=14, setSize=1), (cores=2, mos=[1], ols=1, batchSize=1, instances=7, setSize=1), (cores=4, mos=[1], ols=1, batchSize=1, instances=3, setSize=1), (cores=7, mos=[1], ols=1, batchSize=1, instances=2, setSize=1), (cores=14, mos=[1], ols=1, batchSize=1, instances=1, setSize=1)]
# 2025-04-29 01:39:22.102 - [INFO]: Evaluating the following SearchPoints: [(cores=1, mos=[1], ols=1, batchSize=1, instances=14, setSize=1), (cores=2, mos=[1], ols=1, batchSize=1, instances=7, setSize=1), (cores=4, mos=[1], ols=1, batchSize=1, instances=3, setSize=1), (cores=7, mos=[1], ols=1, batchSize=1, instances=2, setSize=1), (cores=14, mos=[1], ols=1, batchSize=1, instances=1, setSize=1)]
# 2025-04-29 01:39:22.102 - [INFO]: Compiling model: compilerParams=(cores=2, mos=[1], ols=1, batchSize=1)
# 2025-04-29 01:39:22.102 - [INFO]: Compiling model: compilerParams=(cores=1, mos=[1], ols=1, batchSize=1)
# 2025-04-29 01:39:22.103 - [INFO]: Compiling model: compilerParams=(cores=4, mos=[1], ols=1, batchSize=1)
# 2025-04-29 01:39:22.103 - [INFO]: Compiling model: compilerParams=(cores=7, mos=[1], ols=1, batchSize=1)
# 2025-04-29 01:39:22.103 - [INFO]: Compiling model: compilerParams=(cores=14, mos=[1], ols=1, batchSize=1)
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# 2025-04-29 01:41:30.236 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-1-mos-1-ols-1-bs-1-output, runnerParams=instances=14, setSize=1)}
# 2025-04-29 01:41:36.658 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-2-mos-1-ols-1-bs-1-output, runnerParams=instances=7, setSize=1)}
# 2025-04-29 01:41:42.941 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-4-mos-1-ols-1-bs-1-output, runnerParams=instances=3, setSize=1)}
# 2025-04-29 01:41:49.196 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-7-mos-1-ols-1-bs-1-output, runnerParams=instances=2, setSize=1)}
# 2025-04-29 01:41:55.467 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-14-mos-1-ols-1-bs-1-output, runnerParams=instances=1, setSize=1)}
# 2025-04-29 01:42:02.060 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-1-mos-1-ols-1-bs-1-output, runnerParams=instances=14, setSize=1)}
# 2025-04-29 01:42:08.486 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-2-mos-1-ols-1-bs-1-output, runnerParams=instances=7, setSize=1)}
# 2025-04-29 01:42:14.784 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-4-mos-1-ols-1-bs-1-output, runnerParams=instances=3, setSize=1)}
# 2025-04-29 01:42:21.040 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-7-mos-1-ols-1-bs-1-output, runnerParams=instances=2, setSize=1)}
# 2025-04-29 01:42:27.309 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-14-mos-1-ols-1-bs-1-output, runnerParams=instances=1, setSize=1)}
# 2025-04-29 01:42:33.877 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-1-mos-1-ols-1-bs-1-output, runnerParams=instances=14, setSize=1)}
# 2025-04-29 01:42:40.303 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-2-mos-1-ols-1-bs-1-output, runnerParams=instances=7, setSize=1)}
# 2025-04-29 01:42:46.578 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-4-mos-1-ols-1-bs-1-output, runnerParams=instances=3, setSize=1)}
# 2025-04-29 01:42:52.840 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-7-mos-1-ols-1-bs-1-output, runnerParams=instances=2, setSize=1)}
# 2025-04-29 01:42:59.105 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-14-mos-1-ols-1-bs-1-output, runnerParams=instances=1, setSize=1)}
# 2025-04-29 01:43:05.681 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-1-mos-1-ols-1-bs-1-output, runnerParams=instances=14, setSize=1)}
# 2025-04-29 01:43:12.109 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-2-mos-1-ols-1-bs-1-output, runnerParams=instances=7, setSize=1)}
# 2025-04-29 01:43:18.391 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-4-mos-1-ols-1-bs-1-output, runnerParams=instances=3, setSize=1)}
# 2025-04-29 01:43:24.664 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-7-mos-1-ols-1-bs-1-output, runnerParams=instances=2, setSize=1)}
# 2025-04-29 01:43:30.929 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-14-mos-1-ols-1-bs-1-output, runnerParams=instances=1, setSize=1)}
# 2025-04-29 01:43:36.477 - [INFO]: Evaluating the following SearchPoints: [(cores=1, mos=[1], ols=1, batchSize=1, instances=7, setSize=1), (cores=1, mos=[1], ols=1, batchSize=1, instances=13, setSize=1), (cores=1, mos=[1], ols=1, batchSize=1, instances=14, setSize=2), (cores=1, mos=[1], ols=1, batchSize=2, instances=14, setSize=1), (cores=1, mos=[1], ols=2, batchSize=1, instances=14, setSize=1), (cores=2, mos=[1], ols=1, batchSize=1, instances=6, setSize=1), (cores=2, mos=[1], ols=1, batchSize=1, instances=7, setSize=2), (cores=2, mos=[1], ols=1, batchSize=1, instances=8, setSize=1), (cores=2, mos=[1], ols=1, batchSize=2, instances=7, setSize=1), (cores=2, mos=[1], ols=2, batchSize=1, instances=7, setSize=1), (cores=2, mos=[2], ols=1, batchSize=1, instances=7, setSize=1), (cores=3, mos=[1], ols=1, batchSize=1, instances=3, setSize=1), (cores=4, mos=[1], ols=1, batchSize=1, instances=2, setSize=1), (cores=4, mos=[1], ols=1, batchSize=1, instances=3, setSize=2), (cores=4, mos=[1], ols=1, batchSize=1, instances=4, setSize=1), (cores=4, mos=[1], ols=1, batchSize=2, instances=3, setSize=1), (cores=4, mos=[1], ols=2, batchSize=1, instances=3, setSize=1), (cores=4, mos=[2], ols=1, batchSize=1, instances=3, setSize=1), (cores=5, mos=[1], ols=1, batchSize=1, instances=3, setSize=1), (cores=6, mos=[1], ols=1, batchSize=1, instances=2, setSize=1), (cores=7, mos=[1], ols=1, batchSize=1, instances=1, setSize=1), (cores=7, mos=[1], ols=1, batchSize=1, instances=2, setSize=2), (cores=7, mos=[1], ols=1, batchSize=2, instances=2, setSize=1), (cores=7, mos=[1], ols=2, batchSize=1, instances=2, setSize=1), (cores=7, mos=[2], ols=1, batchSize=1, instances=2, setSize=1), (cores=8, mos=[1], ols=1, batchSize=1, instances=2, setSize=1), (cores=13, mos=[1], ols=1, batchSize=1, instances=1, setSize=1), (cores=14, mos=[1], ols=1, batchSize=1, instances=1, setSize=2), (cores=14, mos=[1], ols=1, batchSize=2, instances=1, setSize=1), (cores=14, mos=[1], ols=2, batchSize=1, instances=1, setSize=1), (cores=14, mos=[2], ols=1, batchSize=1, instances=1, setSize=1)]
# 2025-04-29 01:43:36.478 - [INFO]: Compiling model: compilerParams=(cores=1, mos=[1], ols=1, batchSize=2)
# 2025-04-29 01:43:36.478 - [INFO]: Compiling model: compilerParams=(cores=7, mos=[2], ols=1, batchSize=1)
# 2025-04-29 01:43:36.479 - [INFO]: Compiling model: compilerParams=(cores=2, mos=[1], ols=1, batchSize=2)
# 2025-04-29 01:43:36.479 - [INFO]: Compiling model: compilerParams=(cores=2, mos=[1], ols=2, batchSize=1)
# 2025-04-29 01:43:36.479 - [INFO]: Compiling model: compilerParams=(cores=4, mos=[1], ols=2, batchSize=1)
# 2025-04-29 01:43:36.479 - [INFO]: Compiling model: compilerParams=(cores=3, mos=[1], ols=1, batchSize=1)
# 2025-04-29 01:43:36.480 - [INFO]: Compiling model: compilerParams=(cores=4, mos=[2], ols=1, batchSize=1)
# 2025-04-29 01:43:36.480 - [INFO]: Compiling model: compilerParams=(cores=4, mos=[1], ols=1, batchSize=2)
# 2025-04-29 01:43:36.480 - [INFO]: Compiling model: compilerParams=(cores=2, mos=[2], ols=1, batchSize=1)
# 2025-04-29 01:43:36.480 - [INFO]: Compiling model: compilerParams=(cores=5, mos=[1], ols=1, batchSize=1)
# 2025-04-29 01:43:36.480 - [INFO]: Compiling model: compilerParams=(cores=7, mos=[1], ols=1, batchSize=2)
# 2025-04-29 01:43:36.480 - [INFO]: Compiling model: compilerParams=(cores=6, mos=[1], ols=1, batchSize=1)
# 2025-04-29 01:43:36.481 - [INFO]: Compiling model: compilerParams=(cores=7, mos=[1], ols=2, batchSize=1)
# 2025-04-29 01:43:36.481 - [INFO]: Compiling model: compilerParams=(cores=1, mos=[1], ols=2, batchSize=1)
# 2025-04-29 01:43:36.481 - [INFO]: Compiling model: compilerParams=(cores=8, mos=[1], ols=1, batchSize=1)
# 2025-04-29 01:43:36.481 - [INFO]: Compiling model: compilerParams=(cores=13, mos=[1], ols=1, batchSize=1)
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# 2025-04-29 01:45:17.721 - [INFO]: Compiling model: compilerParams=(cores=14, mos=[1], ols=1, batchSize=2)
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# 2025-04-29 01:45:20.594 - [INFO]: Compiling model: compilerParams=(cores=14, mos=[1], ols=2, batchSize=1)
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# 2025-04-29 01:45:29.330 - [INFO]: Compiling model: compilerParams=(cores=14, mos=[2], ols=1, batchSize=1)
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# 2025-04-29 01:48:17.783 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-1-mos-1-ols-1-bs-1-output, runnerParams=instances=7, setSize=1)}
# 2025-04-29 01:48:24.333 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-1-mos-1-ols-1-bs-1-output, runnerParams=instances=13, setSize=1)}
# 2025-04-29 01:48:30.934 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-1-mos-1-ols-1-bs-1-output, runnerParams=instances=14, setSize=2)}
# 2025-04-29 01:48:37.653 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-1-mos-1-ols-1-bs-2-output, runnerParams=instances=14, setSize=1)}
# 2025-04-29 01:48:44.293 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-1-mos-1-ols-2-bs-1-output, runnerParams=instances=14, setSize=1)}
# 2025-04-29 01:48:50.676 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-2-mos-1-ols-1-bs-1-output, runnerParams=instances=6, setSize=1)}
# 2025-04-29 01:48:57.118 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-2-mos-1-ols-1-bs-1-output, runnerParams=instances=7, setSize=2)}
# 2025-04-29 01:49:03.574 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-2-mos-1-ols-1-bs-1-output, runnerParams=instances=8, setSize=1)}
# 2025-04-29 01:49:10.074 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-2-mos-1-ols-1-bs-2-output, runnerParams=instances=7, setSize=1)}
# 2025-04-29 01:49:16.512 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-2-mos-1-ols-2-bs-1-output, runnerParams=instances=7, setSize=1)}
# 2025-04-29 01:49:22.883 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-2-mos-2-ols-1-bs-1-output, runnerParams=instances=7, setSize=1)}
# 2025-04-29 01:49:29.166 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-3-mos-1-ols-1-bs-1-output, runnerParams=instances=3, setSize=1)}
# 2025-04-29 01:49:35.398 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-4-mos-1-ols-1-bs-1-output, runnerParams=instances=2, setSize=1)}
# 2025-04-29 01:49:41.686 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-4-mos-1-ols-1-bs-1-output, runnerParams=instances=3, setSize=2)}
# 2025-04-29 01:49:48.019 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-4-mos-1-ols-1-bs-1-output, runnerParams=instances=4, setSize=1)}
# 2025-04-29 01:49:54.453 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-4-mos-1-ols-1-bs-2-output, runnerParams=instances=3, setSize=1)}
# 2025-04-29 01:50:00.770 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-4-mos-1-ols-2-bs-1-output, runnerParams=instances=3, setSize=1)}
# 2025-04-29 01:50:07.042 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-4-mos-2-ols-1-bs-1-output, runnerParams=instances=3, setSize=1)}
# 2025-04-29 01:50:13.361 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-5-mos-1-ols-1-bs-1-output, runnerParams=instances=3, setSize=1)}
# 2025-04-29 01:50:19.626 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-6-mos-1-ols-1-bs-1-output, runnerParams=instances=2, setSize=1)}
# 2025-04-29 01:50:25.839 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-7-mos-1-ols-1-bs-1-output, runnerParams=instances=1, setSize=1)}
# 2025-04-29 01:50:32.092 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-7-mos-1-ols-1-bs-1-output, runnerParams=instances=2, setSize=2)}
# 2025-04-29 01:50:38.566 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-7-mos-1-ols-1-bs-2-output, runnerParams=instances=2, setSize=1)}
# 2025-04-29 01:50:44.862 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-7-mos-1-ols-2-bs-1-output, runnerParams=instances=2, setSize=1)}
# 2025-04-29 01:50:51.302 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-7-mos-2-ols-1-bs-1-output, runnerParams=instances=2, setSize=1)}
# ...
# [2023-08-13 01:04:38.521] [info] Compiling model with compiler parameters: [(cores=11, mos=[1], ols=1, batchSize=16), (cores=12, mos=[1], ols=1, batchSize=8), (cores=12, mos=[1], ols=2, batchSize=16), (cores=12, mos=[2], ols=1, batchSize=16), (cores=13, mos=[1], ols=1, batchSize=16)]
# [2023-08-13 01:06:01.220] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-11-mos-1-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-08-13 01:06:02.791] [info] Model at path model_configurator_output/compiled_models/qpc-cores-11-mos-1-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-08-13 01:06:08.341] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-12-mos-1-ols-1-bs-8-output with runnerParams (instances=1)
# [2023-08-13 01:06:09.178] [info] Model at path model_configurator_output/compiled_models/qpc-cores-12-mos-1-ols-1-bs-8-output with runnerParams (instances=1) running on device ID 0
# [2023-08-13 01:06:14.722] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-13-mos-1-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-08-13 01:06:16.269] [info] Model at path model_configurator_output/compiled_models/qpc-cores-13-mos-1-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-08-13 01:06:21.822] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-12-mos-2-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-08-13 01:06:23.378] [info] Model at path model_configurator_output/compiled_models/qpc-cores-12-mos-2-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-08-13 01:06:28.926] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-12-mos-1-ols-2-bs-16-output with runnerParams (instances=1)
# [2023-08-13 01:06:30.520] [info] Model at path model_configurator_output/compiled_models/qpc-cores-12-mos-1-ols-2-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-08-13 01:06:36.078] [info] Compiling model with compiler parameters: [(cores=10, mos=[1], ols=1, batchSize=16)]
# [2023-08-13 01:07:38.554] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-10-mos-1-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-08-13 01:07:40.107] [info] Model at path model_configurator_output/compiled_models/qpc-cores-10-mos-1-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-08-13 01:07:45.659] [info] Compiling model with compiler parameters: [(cores=9, mos=[1], ols=1, batchSize=16), (cores=10, mos=[1], ols=1, batchSize=8), (cores=10, mos=[1], ols=2, batchSize=16), (cores=10, mos=[2], ols=1, batchSize=16)]
# [2023-08-13 01:09:07.266] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-9-mos-1-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-08-13 01:09:08.827] [info] Model at path model_configurator_output/compiled_models/qpc-cores-9-mos-1-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-08-13 01:09:14.375] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-10-mos-1-ols-1-bs-8-output with runnerParams (instances=1)
# [2023-08-13 01:09:15.197] [info] Model at path model_configurator_output/compiled_models/qpc-cores-10-mos-1-ols-1-bs-8-output with runnerParams (instances=1) running on device ID 0
# [2023-08-13 01:09:20.239] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-10-mos-2-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-08-13 01:09:21.777] [info] Model at path model_configurator_output/compiled_models/qpc-cores-10-mos-2-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-08-13 01:09:27.334] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-10-mos-1-ols-2-bs-16-output with runnerParams (instances=1)
# [2023-08-13 01:09:28.910] [info] Model at path model_configurator_output/compiled_models/qpc-cores-10-mos-1-ols-2-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-08-13 01:09:34.472] [info] Compiling model with compiler parameters: [(cores=14, mos=[7], ols=1, batchSize=16)]
# [2023-08-13 01:10:49.023] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-14-mos-7-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-08-13 01:10:50.654] [info] Model at path model_configurator_output/compiled_models/qpc-cores-14-mos-7-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-08-13 01:10:56.206] [info] Compiling model with compiler parameters: [(cores=12, mos=[4], ols=1, batchSize=16)]
# [2023-08-13 01:12:07.816] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-12-mos-4-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-08-13 01:12:09.392] [info] Model at path model_configurator_output/compiled_models/qpc-cores-12-mos-4-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-08-13 01:12:14.937] [info] Compiling model with compiler parameters: [(cores=11, mos=[2], ols=1, batchSize=16)]
# [2023-08-13 01:13:23.284] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-11-mos-2-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-08-13 01:13:24.869] [info] Model at path model_configurator_output/compiled_models/qpc-cores-11-mos-2-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-08-13 01:13:30.422] [info] Compiling model with compiler parameters: [(cores=14, mos=[6], ols=1, batchSize=16)]
# [2023-08-13 01:14:46.240] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-14-mos-6-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-08-13 01:14:47.885] [info] Model at path model_configurator_output/compiled_models/qpc-cores-14-mos-6-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-08-13 01:14:53.444] [info] Compiling model with compiler parameters: [(cores=12, mos=[3], ols=1, batchSize=16)]
# [2023-08-13 01:15:59.904] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-12-mos-3-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-08-13 01:16:01.485] [info] Model at path model_configurator_output/compiled_models/qpc-cores-12-mos-3-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-08-13 01:16:07.063] [info] Compiling model with compiler parameters: [(cores=10, mos=[1], ols=3, batchSize=16)]
# [2023-08-13 01:17:27.457] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-10-mos-1-ols-3-bs-16-output with runnerParams (instances=1)
# [2023-08-13 01:17:29.039] [info] Model at path model_configurator_output/compiled_models/qpc-cores-10-mos-1-ols-3-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-08-13 01:17:34.588] [info] Compiling model with compiler parameters: [(cores=9, mos=[1], ols=2, batchSize=16), (cores=10, mos=[1], ols=2, batchSize=8), (cores=10, mos=[2], ols=2, batchSize=16), (cores=11, mos=[1], ols=2, batchSize=16)]
# [2023-08-13 01:19:02.899] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-9-mos-1-ols-2-bs-16-output with runnerParams (instances=1)
# [2023-08-13 01:19:04.469] [info] Model at path model_configurator_output/compiled_models/qpc-cores-9-mos-1-ols-2-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-08-13 01:19:09.529] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-10-mos-1-ols-2-bs-8-output with runnerParams (instances=1)
# [2023-08-13 01:19:10.392] [info] Model at path model_configurator_output/compiled_models/qpc-cores-10-mos-1-ols-2-bs-8-output with runnerParams (instances=1) running on device ID 0
# [2023-08-13 01:19:15.438] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-11-mos-1-ols-2-bs-16-output with runnerParams (instances=1)
# [2023-08-13 01:19:17.002] [info] Model at path model_configurator_output/compiled_models/qpc-cores-11-mos-1-ols-2-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-08-13 01:19:22.556] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-10-mos-2-ols-2-bs-16-output with runnerParams (instances=1)
# [2023-08-13 01:19:24.157] [info] Model at path model_configurator_output/compiled_models/qpc-cores-10-mos-2-ols-2-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-08-13 01:19:29.707] [info] Compiling model with compiler parameters: [(cores=11, mos=[2], ols=8, batchSize=16)]
# [2023-08-13 01:21:23.023] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-11-mos-2-ols-8-bs-16-output with runnerParams (instances=1)
# [2023-08-13 01:21:24.669] [info] Model at path model_configurator_output/compiled_models/qpc-cores-11-mos-2-ols-8-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-08-13 01:21:30.227] [info] Compiling model with compiler parameters: [(cores=10, mos=[1], ols=5, batchSize=16)]
# [2023-08-13 01:23:04.198] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-10-mos-1-ols-5-bs-16-output with runnerParams (instances=1)
# [2023-08-13 01:23:05.832] [info] Model at path model_configurator_output/compiled_models/qpc-cores-10-mos-1-ols-5-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-08-13 01:23:11.385] [info] Compiling model with compiler parameters: [(cores=8, mos=[1], ols=2, batchSize=16)]
# [2023-08-13 01:24:17.925] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-8-mos-1-ols-2-bs-16-output with runnerParams (instances=1)
# [2023-08-13 01:24:19.484] [info] Model at path model_configurator_output/compiled_models/qpc-cores-8-mos-1-ols-2-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-08-13 01:24:25.039] [info] Compiling model with compiler parameters: [(cores=9, mos=[1], ols=2, batchSize=8), (cores=9, mos=[1], ols=3, batchSize=16), (cores=9, mos=[2], ols=2, batchSize=16)]
# [2023-08-13 01:25:48.562] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-9-mos-1-ols-2-bs-8-output with runnerParams (instances=1)
# [2023-08-13 01:25:49.421] [info] Model at path model_configurator_output/compiled_models/qpc-cores-9-mos-1-ols-2-bs-8-output with runnerParams (instances=1) running on device ID 0
# [2023-08-13 01:25:54.464] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-9-mos-2-ols-2-bs-16-output with runnerParams (instances=1)
# [2023-08-13 01:25:56.048] [info] Model at path model_configurator_output/compiled_models/qpc-cores-9-mos-2-ols-2-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-08-13 01:26:01.606] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-9-mos-1-ols-3-bs-16-output with runnerParams (instances=1)
# [2023-08-13 01:26:03.184] [info] Model at path model_configurator_output/compiled_models/qpc-cores-9-mos-1-ols-3-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-08-13 01:26:08.741] [info] Compiling model with compiler parameters: [(cores=9, mos=[1], ols=8, batchSize=16)]
# [2023-08-13 01:27:56.292] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-9-mos-1-ols-8-bs-16-output with runnerParams (instances=1)
# [2023-08-13 01:27:57.888] [info] Model at path model_configurator_output/compiled_models/qpc-cores-9-mos-1-ols-8-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-08-13 01:28:03.439] [info] Compiling model with compiler parameters: [(cores=9, mos=[1], ols=5, batchSize=16)]
# [2023-08-13 01:29:34.123] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-9-mos-1-ols-5-bs-16-output with runnerParams (instances=1)
# [2023-08-13 01:29:35.774] [info] Model at path model_configurator_output/compiled_models/qpc-cores-9-mos-1-ols-5-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-08-13 01:29:41.337] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-7-mos-1-ols-2-bs-16-output with runnerParams (instances=1)
# [2023-08-13 01:29:42.900] [info] Model at path model_configurator_output/compiled_models/qpc-cores-7-mos-1-ols-2-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-08-13 01:29:48.453] [info] Compiling model with compiler parameters: [(cores=8, mos=[1], ols=1, batchSize=16), (cores=8, mos=[1], ols=2, batchSize=8), (cores=8, mos=[1], ols=3, batchSize=16), (cores=8, mos=[2], ols=2, batchSize=16)]
# [2023-08-13 01:31:10.715] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-8-mos-1-ols-1-bs-16-output with runnerParams (instances=1)
# [2023-08-13 01:31:12.256] [info] Model at path model_configurator_output/compiled_models/qpc-cores-8-mos-1-ols-1-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-08-13 01:31:17.315] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-8-mos-1-ols-2-bs-8-output with runnerParams (instances=1)
# [2023-08-13 01:31:18.138] [info] Model at path model_configurator_output/compiled_models/qpc-cores-8-mos-1-ols-2-bs-8-output with runnerParams (instances=1) running on device ID 0
# [2023-08-13 01:31:23.184] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-8-mos-2-ols-2-bs-16-output with runnerParams (instances=1)
# [2023-08-13 01:31:24.732] [info] Model at path model_configurator_output/compiled_models/qpc-cores-8-mos-2-ols-2-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-08-13 01:31:30.277] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-8-mos-1-ols-3-bs-16-output with runnerParams (instances=1)
# [2023-08-13 01:31:31.815] [info] Model at path model_configurator_output/compiled_models/qpc-cores-8-mos-1-ols-3-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-08-13 01:31:37.374] [info] Compiling model with compiler parameters: [(cores=8, mos=[1], ols=8, batchSize=16)]
# [2023-08-13 01:32:59.989] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-8-mos-1-ols-8-bs-16-output with runnerParams (instances=1)
# [2023-08-13 01:33:01.560] [info] Model at path model_configurator_output/compiled_models/qpc-cores-8-mos-1-ols-8-bs-16-output with runnerParams (instances=1) running on device ID 0
# [2023-08-13 01:33:07.116] [info] Compiling model with compiler parameters: [(cores=8, mos=[1], ols=5, batchSize=16)]
# [2023-08-13 01:34:28.538] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-8-mos-1-ols-5-bs-16-output with runnerParams (instances=1)
# [2023-08-13 01:34:30.145] [info] Model at path model_configurator_output/compiled_models/qpc-cores-8-mos-1-ols-5-bs-16-output with runnerParams (instances=1) running on device ID 0
# 2023-08-13 01:34:36.417 - [INFO]: Optimized search results:
#   OptimizerStatus                      InitialValue                      cores mos   ols  batchSize  instances  Objective (inf/sec)
# 0      SUCCESS     (cores=1, mos=[1], ols=1, batchSize=1, instances=14)    1    [1]   2       2         14            4419.97
# 1      SUCCESS      (cores=2, mos=[1], ols=1, batchSize=1, instances=7)    2    [1]   2       4          7            6418.51
# 2      SUCCESS      (cores=4, mos=[1], ols=1, batchSize=1, instances=3)    5    [1]   2       8          2            5473.46
# 3      SUCCESS      (cores=7, mos=[1], ols=1, batchSize=1, instances=2)    7    [1]   3      16          2            6091.01
# 4      SUCCESS     (cores=14, mos=[1], ols=1, batchSize=1, instances=1)    8    [1]   2      16          1            5616.04
# 2023-08-13 01:34:36.419 - [INFO]: Total execution time 01:28:27.477

# %% [markdown]
# ## Measure end-to-end latency
#
# Here are the steps to measure the end-to-end latency as well as the breakdown of latency for the best configuration identified in the previous step. (Configurations depend on the card variant that the test is being run on).
#
# 1. Compile the model using 'qaic-exec'with the configuration parameters identified in previous step using model configurator.
# 2. Execute the compiled model using 'qaic-runner' with the run time parameters identified in previous step using model configurator. Run 'qaic-runner' with flags that dump latency information.
# 3. Post process the latency information to identify percentile distribution (mean, median, 95 and 99) in latency across inferences.

# %%
## Compile the model 

# !rm -rf compiled_fp16
# !/opt/qti-aic/exec/qaic-exec -v -aic-hw  \
-m=resnet-50_onnx/model.onnx \
-onnx-define-symbol=batch_size,4 \
-onnx-define-symbol=num_channels,3 -onnx-define-symbol=height,224  -onnx-define-symbol=width,224 \
-mos=1 -ols=2 -aic-num-cores=2 \
-stats-batchsize=4 -aic-binary-dir=./compiled_fp16 \
-multicast-weights -convert-to-fp16 \
-aic-hw-version=2.0 -compile-only
# Out:
# Reading ONNX Model from resnet-50_onnx/model.onnx
# Compile started ...............
# Compiling model with FP16 precision.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# Generated binary is present at ./compiled_fp16

# %%
## Execute the compiled model with the latency flags. qaic-runner generates random data if input data is not passed to it. 
# !mkdir resnet50_stats
# !/opt/qti-aic/exec/qaic-runner --test-data ./compiled_fp16  -d 0 -a 7 -S 10\
--aic-profiling-type latency --aic-profiling-out-dir ./resnet50_stats \
--aic-profiling-start-iter 100 --aic-profiling-num-samples 9999 --time 20
# Out:
# mkdir: cannot create directory ‘resnet50_stats’: File exists
# Using bounded random inputs
#  ---- Stats ----
# InferenceCnt 21961 TotalDuration 20063118us BatchSize 4 Inf/Sec 4378.382
# Deleting previous file: ./resnet50_stats/aic-profiling-program-1-latency.txt
# Writing file:./resnet50_stats/aic-profiling-program-1-latency.txt
# Deleting previous file: ./resnet50_stats/aic-profiling-program-2-latency.txt
# Writing file:./resnet50_stats/aic-profiling-program-2-latency.txt
# Deleting previous file: ./resnet50_stats/aic-profiling-program-3-latency.txt
# Writing file:./resnet50_stats/aic-profiling-program-3-latency.txt
# Deleting previous file: ./resnet50_stats/aic-profiling-program-4-latency.txt
# Writing file:./resnet50_stats/aic-profiling-program-4-latency.txt
# Deleting previous file: ./resnet50_stats/aic-profiling-program-5-latency.txt
# Writing file:./resnet50_stats/aic-profiling-program-5-latency.txt
# Deleting previous file: ./resnet50_stats/aic-profiling-program-6-latency.txt
# Writing file:./resnet50_stats/aic-profiling-program-6-latency.txt
# Deleting previous file: ./resnet50_stats/aic-profiling-program-7-latency.txt
# Writing file:./resnet50_stats/aic-profiling-program-7-latency.txt

# %% [markdown]
# ### Latency breakdown
#
# The end-to-end inference latency can be broken down into 4 major categories - Application, Linux Runtime (LRT) processing, Kernel mode driver (KMD) processing and Cloud AI device processing.
#
#
# ![Latency Breakdown](Images/Latency.jpg)
#
# **Key Latency Stats** (units in us)
# - *totalRoundtripTime* :Time from point where application (qaic-runner in this case) calls Runtime API and ends where post-processing is complete and control is returned to the application indicating the inference is complete
# - *preProcTime* : Time taken to pre-process the data (model input) on the host
# - *postProc* : Time taken to post-process the data (model output) on the host
# - *execTotal* : Time from inference object being submitted to kernel, completion on hardware and processing is returned to user-space

# %%
## Post process the latency information to identify percentile distribution

# !python3 latency_stats_python3.py ./resnet50_stats/aic-profiling-program-1-latency.txt \
./resnet50_stats/aic-profiling-program-2-latency.txt \
./resnet50_stats/aic-profiling-program-3-latency.txt \
./resnet50_stats/aic-profiling-program-4-latency.txt \
./resnet50_stats/aic-profiling-program-5-latency.txt \
./resnet50_stats/aic-profiling-program-6-latency.txt \
./resnet50_stats/aic-profiling-program-7-latency.txt
# Out:
# All activations combined:
#                          mean        min        50%        75%        90%        95%        99%        max
# hostRoundTrip       63.493598  60.455000  63.435000  63.760000  64.117000  64.360000  64.986400  65.911000
# enqTime              0.002446   0.000560   0.002050   0.002380   0.002770   0.003290   0.016102   0.186710
# preProcTime          0.287521   0.144060   0.277910   0.333430   0.392240   0.421280   0.523566   1.219299
# submitTime           0.001639   0.000710   0.001590   0.001930   0.002050   0.002130   0.002480   0.185560
# execTotal           63.537078  60.477856  63.478268  63.804134  64.161848  64.406808  65.036487  65.964993
# exectoVc             0.004797   0.003000   0.005000   0.005000   0.006000   0.006000   0.010000   0.210000
# execToComplete      63.488802  60.449000  63.430000  63.755000  64.113000  64.355000  64.982000  65.906000
# postProc             0.004934   0.002190   0.004680   0.005750   0.006660   0.007190   0.008720   0.198510
# totalRoundtripTime  63.868783  62.678998  63.803204  64.131874  64.482984  64.721988  65.355114  66.299834
# totalRoundtripTime: percentile(mean) = 63.869 ms

# %% [markdown]
# As observed, for the configuration choosen, throughput of ~4380 images/sec is observed with a mean latency of ~64ms per batched (bs=4) inference.

# %% [markdown]
# # <span style='color:Blue'> 5. Identify the least latency configuration </span>
#
# Identifying the least latency configurations requires the users to run the model_configurator tool with the "objective" parameter set to "minimize_latency".
#
# Minimum latency is achieved when the batch-size, instances and set-size are set to 1.
# We need to iterate through the cores used to compile the network to identify the least latency config.
#
# The key difference in the dopt.json files used for best throughput vs least latency are in the initial values. The number of instances is always set to 1 for least latency. For best throughput, the initial value of instances = floor((total no of cores in the device) / (no of cores used to compile the model))
#
# Lets go through these steps for the resnet50 model.

# %%
# !python3 /opt/qti-aic/scripts/qaic-model-configurator/model_configurator.py -model resnet-50_onnx/model.onnx  \
-onnx-define-symbol-batch-size=batch_size \
-onnx-define-symbol=num_channels,3 -onnx-define-symbol=height,224  -onnx-define-symbol=width,224 \
-multicast-weights \
-config=resnet_base_dopt_min_latency.json -max-parallel-compilations=16 -time=5 \
-convert-to-fp16 -device-id=0 -search-set-size 1
# Out:
# 2025-04-30 00:15:23.852 - [INFO]: Starting /opt/qti-aic/scripts/qaic-model-configurator/model_configurator.py -model resnet-50_onnx/model.onnx -onnx-define-symbol-batch-size=batch_size -onnx-define-symbol=num_channels,3 -onnx-define-symbol=height,224 -onnx-define-symbol=width,224 -multicast-weights -config=resnet_base_dopt_min_latency.json -max-parallel-compilations=16 -time=5 -convert-to-fp16 -device-id=0 -search-set-size 1
# 2025-04-30 00:15:23.854 - [INFO]: Hostname: qrc706r11-282-07, Physical Cores: 48, Logical Cores: 48, Memory: 503.8 GB
# 2025-04-30 00:15:24.124 - [INFO]: Running optimized search
# 2025-04-30 00:15:24.140 - [INFO]: Running optimization algorithm from initial values: [(cores=1, mos=[1], ols=1, batchSize=1, instances=1), (cores=2, mos=[1], ols=1, batchSize=1, instances=1), (cores=4, mos=[1], ols=1, batchSize=1, instances=1), (cores=7, mos=[1], ols=1, batchSize=1, instances=1), (cores=14, mos=[1], ols=1, batchSize=1, instances=1)]
# 2025-04-30 00:15:24.140 - [INFO]: Evaluating the following SearchPoints: [(cores=1, mos=[1], ols=1, batchSize=1, instances=1), (cores=2, mos=[1], ols=1, batchSize=1, instances=1), (cores=4, mos=[1], ols=1, batchSize=1, instances=1), (cores=7, mos=[1], ols=1, batchSize=1, instances=1), (cores=14, mos=[1], ols=1, batchSize=1, instances=1)]
# 2025-04-30 00:15:24.140 - [INFO]: Compiling model: compilerParams=(cores=1, mos=[1], ols=1, batchSize=1)
# 2025-04-30 00:15:24.140 - [INFO]: Compiling model: compilerParams=(cores=14, mos=[1], ols=1, batchSize=1)
# 2025-04-30 00:15:24.141 - [INFO]: Compiling model: compilerParams=(cores=7, mos=[1], ols=1, batchSize=1)
# 2025-04-30 00:15:24.141 - [INFO]: Compiling model: compilerParams=(cores=4, mos=[1], ols=1, batchSize=1)
# 2025-04-30 00:15:24.141 - [INFO]: Compiling model: compilerParams=(cores=2, mos=[1], ols=1, batchSize=1)
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# 2025-04-30 00:17:33.180 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-1-mos-1-ols-1-bs-1-output, runnerParams=instances=1)}
# 2025-04-30 00:17:39.329 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-2-mos-1-ols-1-bs-1-output, runnerParams=instances=1)}
# 2025-04-30 00:17:45.487 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-4-mos-1-ols-1-bs-1-output, runnerParams=instances=1)}
# 2025-04-30 00:17:51.667 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-7-mos-1-ols-1-bs-1-output, runnerParams=instances=1)}
# 2025-04-30 00:17:57.899 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-14-mos-1-ols-1-bs-1-output, runnerParams=instances=1)}
# 2025-04-30 00:18:03.424 - [INFO]: Evaluating the following SearchPoints: [(cores=1, mos=[1], ols=1, batchSize=1, instances=1), (cores=1, mos=[1], ols=1, batchSize=1, instances=2), (cores=1, mos=[1], ols=1, batchSize=2, instances=1), (cores=1, mos=[1], ols=2, batchSize=1, instances=1), (cores=2, mos=[1], ols=1, batchSize=1, instances=1), (cores=2, mos=[1], ols=1, batchSize=1, instances=2), (cores=2, mos=[1], ols=1, batchSize=2, instances=1), (cores=2, mos=[1], ols=2, batchSize=1, instances=1), (cores=2, mos=[2], ols=1, batchSize=1, instances=1), (cores=3, mos=[1], ols=1, batchSize=1, instances=1), (cores=4, mos=[1], ols=1, batchSize=1, instances=2), (cores=4, mos=[1], ols=1, batchSize=2, instances=1), (cores=4, mos=[1], ols=2, batchSize=1, instances=1), (cores=4, mos=[2], ols=1, batchSize=1, instances=1), (cores=5, mos=[1], ols=1, batchSize=1, instances=1), (cores=6, mos=[1], ols=1, batchSize=1, instances=1), (cores=7, mos=[1], ols=1, batchSize=1, instances=2), (cores=7, mos=[1], ols=1, batchSize=2, instances=1), (cores=7, mos=[1], ols=2, batchSize=1, instances=1), (cores=7, mos=[2], ols=1, batchSize=1, instances=1), (cores=8, mos=[1], ols=1, batchSize=1, instances=1), (cores=13, mos=[1], ols=1, batchSize=1, instances=1), (cores=14, mos=[1], ols=1, batchSize=2, instances=1), (cores=14, mos=[1], ols=2, batchSize=1, instances=1), (cores=14, mos=[2], ols=1, batchSize=1, instances=1)]
# 2025-04-30 00:18:03.425 - [INFO]: Compiling model: compilerParams=(cores=1, mos=[1], ols=1, batchSize=2)
# 2025-04-30 00:18:03.426 - [INFO]: Compiling model: compilerParams=(cores=1, mos=[1], ols=2, batchSize=1)
# 2025-04-30 00:18:03.426 - [INFO]: Compiling model: compilerParams=(cores=4, mos=[1], ols=1, batchSize=2)
# 2025-04-30 00:18:03.426 - [INFO]: Compiling model: compilerParams=(cores=4, mos=[2], ols=1, batchSize=1)
# 2025-04-30 00:18:03.426 - [INFO]: Compiling model: compilerParams=(cores=6, mos=[1], ols=1, batchSize=1)
# 2025-04-30 00:18:03.427 - [INFO]: Compiling model: compilerParams=(cores=7, mos=[1], ols=1, batchSize=2)
# 2025-04-30 00:18:03.427 - [INFO]: Compiling model: compilerParams=(cores=7, mos=[1], ols=2, batchSize=1)
# 2025-04-30 00:18:03.428 - [INFO]: Compiling model: compilerParams=(cores=7, mos=[2], ols=1, batchSize=1)
# 2025-04-30 00:18:03.428 - [INFO]: Compiling model: compilerParams=(cores=8, mos=[1], ols=1, batchSize=1)
# 2025-04-30 00:18:03.428 - [INFO]: Compiling model: compilerParams=(cores=13, mos=[1], ols=1, batchSize=1)
# 2025-04-30 00:18:03.428 - [INFO]: Compiling model: compilerParams=(cores=2, mos=[1], ols=1, batchSize=2)
# 2025-04-30 00:18:03.428 - [INFO]: Compiling model: compilerParams=(cores=2, mos=[1], ols=2, batchSize=1)
# 2025-04-30 00:18:03.428 - [INFO]: Compiling model: compilerParams=(cores=2, mos=[2], ols=1, batchSize=1)
# 2025-04-30 00:18:03.429 - [INFO]: Compiling model: compilerParams=(cores=3, mos=[1], ols=1, batchSize=1)
# 2025-04-30 00:18:03.429 - [INFO]: Compiling model: compilerParams=(cores=4, mos=[1], ols=2, batchSize=1)
# 2025-04-30 00:18:03.429 - [INFO]: Compiling model: compilerParams=(cores=5, mos=[1], ols=1, batchSize=1)
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# 2025-04-30 00:19:45.107 - [INFO]: Compiling model: compilerParams=(cores=14, mos=[1], ols=1, batchSize=2)
# 2025-04-30 00:19:45.282 - [INFO]: Compiling model: compilerParams=(cores=14, mos=[1], ols=2, batchSize=1)
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# 2025-04-30 00:19:53.199 - [INFO]: Compiling model: compilerParams=(cores=14, mos=[2], ols=1, batchSize=1)
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# 2025-04-30 00:22:39.731 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-1-mos-1-ols-1-bs-1-output, runnerParams=instances=1)}
# 2025-04-30 00:22:45.932 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-1-mos-1-ols-1-bs-1-output, runnerParams=instances=2)}
# 2025-04-30 00:22:52.200 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-1-mos-1-ols-1-bs-2-output, runnerParams=instances=1)}
# 2025-04-30 00:22:58.370 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-1-mos-1-ols-2-bs-1-output, runnerParams=instances=1)}
# 2025-04-30 00:23:04.548 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-2-mos-1-ols-1-bs-1-output, runnerParams=instances=1)}
# 2025-04-30 00:23:10.766 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-2-mos-1-ols-1-bs-1-output, runnerParams=instances=2)}
# 2025-04-30 00:23:17.029 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-2-mos-1-ols-1-bs-2-output, runnerParams=instances=1)}
# 2025-04-30 00:23:23.206 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-2-mos-1-ols-2-bs-1-output, runnerParams=instances=1)}
# 2025-04-30 00:23:29.377 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-2-mos-2-ols-1-bs-1-output, runnerParams=instances=1)}
# 2025-04-30 00:23:35.560 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-3-mos-1-ols-1-bs-1-output, runnerParams=instances=1)}
# 2025-04-30 00:23:41.789 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-4-mos-1-ols-1-bs-1-output, runnerParams=instances=2)}
# 2025-04-30 00:23:48.103 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-4-mos-1-ols-1-bs-2-output, runnerParams=instances=1)}
# 2025-04-30 00:23:54.294 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-4-mos-1-ols-2-bs-1-output, runnerParams=instances=1)}
# 2025-04-30 00:24:00.478 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-4-mos-2-ols-1-bs-1-output, runnerParams=instances=1)}
# 2025-04-30 00:24:06.728 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-5-mos-1-ols-1-bs-1-output, runnerParams=instances=1)}
# 2025-04-30 00:24:12.928 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-6-mos-1-ols-1-bs-1-output, runnerParams=instances=1)}
# 2025-04-30 00:24:19.218 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-7-mos-1-ols-1-bs-1-output, runnerParams=instances=2)}
# 2025-04-30 00:24:25.629 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-7-mos-1-ols-1-bs-2-output, runnerParams=instances=1)}
# 2025-04-30 00:24:31.849 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-7-mos-1-ols-2-bs-1-output, runnerParams=instances=1)}
# 2025-04-30 00:24:38.213 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-7-mos-2-ols-1-bs-1-output, runnerParams=instances=1)}
# 2025-04-30 00:24:44.419 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-8-mos-1-ols-1-bs-1-output, runnerParams=instances=1)}
# 2025-04-30 00:24:50.723 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-13-mos-1-ols-1-bs-1-output, runnerParams=instances=1)}
# 2025-04-30 00:24:57.051 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-14-mos-1-ols-1-bs-2-output, runnerParams=instances=1)}
# 2025-04-30 00:25:03.407 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-14-mos-1-ols-2-bs-1-output, runnerParams=instances=1)}
# 2025-04-30 00:25:09.798 - [INFO]: Running the following set of models on device ID 0: {"model": (compiledModelPath=model_configurator_output/compiled_models/model/qpc-cores-14-mos-2-ols-1-bs-1-output, runnerParams=instances=1)}
# 2025-04-30 00:25:15.350 - [INFO]: Evaluating the following SearchPoints: [(cores=8, mos=[2], ols=1, batchSize=1, instances=1), (cores=9, mos=[1], ols=1, batchSize=1, instances=1), (cores=9, mos=[7], ols=2, batchSize=1, instances=1), (cores=12, mos=[1], ols=1, batchSize=1, instances=1), (cores=14, mos=[1], ols=1, batchSize=1, instances=1)]
# 2025-04-30 00:25:15.351 - [INFO]: Compiling model: compilerParams=(cores=8, mos=[2], ols=1, batchSize=1)
# 2025-04-30 00:25:15.352 - [INFO]: Compiling model: compilerParams=(cores=12, mos=[1], ols=1, batchSize=1)
# 2025-04-30 00:25:15.352 - [INFO]: Compiling model: compilerParams=(cores=9, mos=[7], ols=2, batchSize=1)
# 2025-04-30 00:25:15.352 - [INFO]: Compiling model: compilerParams=(cores=9, mos=[1], ols=1, batchSize=1)
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# ...
# [2023-08-14 01:04:56.482] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-13-mos-1-ols-1-bs-2-output with runnerParams (instances=1)
# [2023-08-14 01:04:56.809] [info] Model at path model_configurator_output/compiled_models/qpc-cores-13-mos-1-ols-1-bs-2-output with runnerParams (instances=1) running on device ID 0
# [2023-08-14 01:05:01.860] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-13-mos-2-ols-1-bs-1-output with runnerParams (instances=1)
# [2023-08-14 01:05:02.122] [info] Model at path model_configurator_output/compiled_models/qpc-cores-13-mos-2-ols-1-bs-1-output with runnerParams (instances=1) running on device ID 0
# [2023-08-14 01:05:07.158] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-13-mos-1-ols-2-bs-1-output with runnerParams (instances=1)
# [2023-08-14 01:05:07.463] [info] Model at path model_configurator_output/compiled_models/qpc-cores-13-mos-1-ols-2-bs-1-output with runnerParams (instances=1) running on device ID 0
# [2023-08-14 01:05:12.502] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-13-mos-1-ols-1-bs-2-output with runnerParams (instances=1)
# [2023-08-14 01:05:12.823] [info] Model at path model_configurator_output/compiled_models/qpc-cores-13-mos-1-ols-1-bs-2-output with runnerParams (instances=1) running on device ID 0
# [2023-08-14 01:05:17.874] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-13-mos-2-ols-1-bs-1-output with runnerParams (instances=1)
# [2023-08-14 01:05:18.133] [info] Model at path model_configurator_output/compiled_models/qpc-cores-13-mos-2-ols-1-bs-1-output with runnerParams (instances=1) running on device ID 0
# [2023-08-14 01:05:23.167] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-13-mos-1-ols-2-bs-1-output with runnerParams (instances=1)
# [2023-08-14 01:05:23.469] [info] Model at path model_configurator_output/compiled_models/qpc-cores-13-mos-1-ols-2-bs-1-output with runnerParams (instances=1) running on device ID 0
# [2023-08-14 01:05:28.505] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-13-mos-1-ols-1-bs-2-output with runnerParams (instances=1)
# [2023-08-14 01:05:28.816] [info] Model at path model_configurator_output/compiled_models/qpc-cores-13-mos-1-ols-1-bs-2-output with runnerParams (instances=1) running on device ID 0
# [2023-08-14 01:05:33.860] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-13-mos-2-ols-1-bs-1-output with runnerParams (instances=1)
# [2023-08-14 01:05:34.115] [info] Model at path model_configurator_output/compiled_models/qpc-cores-13-mos-2-ols-1-bs-1-output with runnerParams (instances=1) running on device ID 0
# [2023-08-14 01:05:39.149] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-13-mos-1-ols-2-bs-1-output with runnerParams (instances=1)
# [2023-08-14 01:05:39.448] [info] Model at path model_configurator_output/compiled_models/qpc-cores-13-mos-1-ols-2-bs-1-output with runnerParams (instances=1) running on device ID 0
# [2023-08-14 01:05:44.487] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-13-mos-1-ols-1-bs-2-output with runnerParams (instances=1)
# [2023-08-14 01:05:44.807] [info] Model at path model_configurator_output/compiled_models/qpc-cores-13-mos-1-ols-1-bs-2-output with runnerParams (instances=1) running on device ID 0
# [2023-08-14 01:05:49.858] [info] Compiling model with compiler parameters: [(cores=7, mos=[1], ols=1, batchSize=1)]
# [2023-08-14 01:06:42.373] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-7-mos-1-ols-1-bs-1-output with runnerParams (instances=1)
# [2023-08-14 01:06:42.576] [info] Model at path model_configurator_output/compiled_models/qpc-cores-7-mos-1-ols-1-bs-1-output with runnerParams (instances=1) running on device ID 0
# [2023-08-14 01:06:47.612] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-7-mos-1-ols-1-bs-1-output with runnerParams (instances=1)
# [2023-08-14 01:06:47.819] [info] Model at path model_configurator_output/compiled_models/qpc-cores-7-mos-1-ols-1-bs-1-output with runnerParams (instances=1) running on device ID 0
# [2023-08-14 01:06:52.855] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-7-mos-1-ols-1-bs-1-output with runnerParams (instances=1)
# [2023-08-14 01:06:53.053] [info] Model at path model_configurator_output/compiled_models/qpc-cores-7-mos-1-ols-1-bs-1-output with runnerParams (instances=1) running on device ID 0
# [2023-08-14 01:06:58.087] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-7-mos-1-ols-1-bs-1-output with runnerParams (instances=1)
# [2023-08-14 01:06:58.289] [info] Model at path model_configurator_output/compiled_models/qpc-cores-7-mos-1-ols-1-bs-1-output with runnerParams (instances=1) running on device ID 0
# [2023-08-14 01:07:03.323] [info] Compiling model with compiler parameters: [(cores=7, mos=[1], ols=1, batchSize=2), (cores=7, mos=[1], ols=2, batchSize=1), (cores=7, mos=[2], ols=1, batchSize=1)]
# [2023-08-14 01:08:08.361] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-7-mos-2-ols-1-bs-1-output with runnerParams (instances=1)
# [2023-08-14 01:08:08.589] [info] Model at path model_configurator_output/compiled_models/qpc-cores-7-mos-2-ols-1-bs-1-output with runnerParams (instances=1) running on device ID 0
# [2023-08-14 01:08:13.628] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-7-mos-1-ols-2-bs-1-output with runnerParams (instances=1)
# [2023-08-14 01:08:13.863] [info] Model at path model_configurator_output/compiled_models/qpc-cores-7-mos-1-ols-2-bs-1-output with runnerParams (instances=1) running on device ID 0
# [2023-08-14 01:08:18.897] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-7-mos-1-ols-1-bs-2-output with runnerParams (instances=1)
# [2023-08-14 01:08:19.201] [info] Model at path model_configurator_output/compiled_models/qpc-cores-7-mos-1-ols-1-bs-2-output with runnerParams (instances=1) running on device ID 0
# [2023-08-14 01:08:24.236] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-7-mos-1-ols-1-bs-1-output with runnerParams (instances=2)
# [2023-08-14 01:08:24.502] [info] Model at path model_configurator_output/compiled_models/qpc-cores-7-mos-1-ols-1-bs-1-output with runnerParams (instances=2) running on device ID 0
# [2023-08-14 01:08:29.565] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-7-mos-2-ols-1-bs-1-output with runnerParams (instances=1)
# [2023-08-14 01:08:29.784] [info] Model at path model_configurator_output/compiled_models/qpc-cores-7-mos-2-ols-1-bs-1-output with runnerParams (instances=1) running on device ID 0
# [2023-08-14 01:08:34.823] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-7-mos-1-ols-2-bs-1-output with runnerParams (instances=1)
# [2023-08-14 01:08:35.052] [info] Model at path model_configurator_output/compiled_models/qpc-cores-7-mos-1-ols-2-bs-1-output with runnerParams (instances=1) running on device ID 0
# [2023-08-14 01:08:40.089] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-7-mos-1-ols-1-bs-2-output with runnerParams (instances=1)
# [2023-08-14 01:08:40.392] [info] Model at path model_configurator_output/compiled_models/qpc-cores-7-mos-1-ols-1-bs-2-output with runnerParams (instances=1) running on device ID 0
# [2023-08-14 01:08:45.435] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-7-mos-1-ols-1-bs-1-output with runnerParams (instances=2)
# [2023-08-14 01:08:45.697] [info] Model at path model_configurator_output/compiled_models/qpc-cores-7-mos-1-ols-1-bs-1-output with runnerParams (instances=2) running on device ID 0
# [2023-08-14 01:08:50.744] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-7-mos-2-ols-1-bs-1-output with runnerParams (instances=1)
# [2023-08-14 01:08:50.957] [info] Model at path model_configurator_output/compiled_models/qpc-cores-7-mos-2-ols-1-bs-1-output with runnerParams (instances=1) running on device ID 0
# [2023-08-14 01:08:56.001] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-7-mos-1-ols-2-bs-1-output with runnerParams (instances=1)
# [2023-08-14 01:08:56.224] [info] Model at path model_configurator_output/compiled_models/qpc-cores-7-mos-1-ols-2-bs-1-output with runnerParams (instances=1) running on device ID 0
# [2023-08-14 01:09:01.259] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-7-mos-1-ols-1-bs-2-output with runnerParams (instances=1)
# [2023-08-14 01:09:01.555] [info] Model at path model_configurator_output/compiled_models/qpc-cores-7-mos-1-ols-1-bs-2-output with runnerParams (instances=1) running on device ID 0
# [2023-08-14 01:09:06.588] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-7-mos-1-ols-1-bs-1-output with runnerParams (instances=2)
# [2023-08-14 01:09:06.855] [info] Model at path model_configurator_output/compiled_models/qpc-cores-7-mos-1-ols-1-bs-1-output with runnerParams (instances=2) running on device ID 0
# [2023-08-14 01:09:11.913] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-7-mos-2-ols-1-bs-1-output with runnerParams (instances=1)
# [2023-08-14 01:09:12.121] [info] Model at path model_configurator_output/compiled_models/qpc-cores-7-mos-2-ols-1-bs-1-output with runnerParams (instances=1) running on device ID 0
# [2023-08-14 01:09:17.155] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-7-mos-1-ols-2-bs-1-output with runnerParams (instances=1)
# [2023-08-14 01:09:17.386] [info] Model at path model_configurator_output/compiled_models/qpc-cores-7-mos-1-ols-2-bs-1-output with runnerParams (instances=1) running on device ID 0
# [2023-08-14 01:09:22.420] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-7-mos-1-ols-1-bs-2-output with runnerParams (instances=1)
# [2023-08-14 01:09:22.719] [info] Model at path model_configurator_output/compiled_models/qpc-cores-7-mos-1-ols-1-bs-2-output with runnerParams (instances=1) running on device ID 0
# [2023-08-14 01:09:27.758] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-7-mos-1-ols-1-bs-1-output with runnerParams (instances=2)
# [2023-08-14 01:09:28.021] [info] Model at path model_configurator_output/compiled_models/qpc-cores-7-mos-1-ols-1-bs-1-output with runnerParams (instances=2) running on device ID 0
# [2023-08-14 01:09:33.085] [info] Compiling model with compiler parameters: [(cores=14, mos=[1], ols=1, batchSize=2), (cores=14, mos=[1], ols=2, batchSize=1), (cores=14, mos=[2], ols=1, batchSize=1)]
# [2023-08-14 01:11:24.010] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-14-mos-2-ols-1-bs-1-output with runnerParams (instances=1)
# [2023-08-14 01:11:24.296] [info] Model at path model_configurator_output/compiled_models/qpc-cores-14-mos-2-ols-1-bs-1-output with runnerParams (instances=1) running on device ID 0
# [2023-08-14 01:11:29.333] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-14-mos-1-ols-2-bs-1-output with runnerParams (instances=1)
# [2023-08-14 01:11:29.607] [info] Model at path model_configurator_output/compiled_models/qpc-cores-14-mos-1-ols-2-bs-1-output with runnerParams (instances=1) running on device ID 0
# [2023-08-14 01:11:34.652] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-14-mos-1-ols-1-bs-2-output with runnerParams (instances=1)
# [2023-08-14 01:11:34.966] [info] Model at path model_configurator_output/compiled_models/qpc-cores-14-mos-1-ols-1-bs-2-output with runnerParams (instances=1) running on device ID 0
# [2023-08-14 01:11:40.015] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-14-mos-2-ols-1-bs-1-output with runnerParams (instances=1)
# [2023-08-14 01:11:40.283] [info] Model at path model_configurator_output/compiled_models/qpc-cores-14-mos-2-ols-1-bs-1-output with runnerParams (instances=1) running on device ID 0
# [2023-08-14 01:11:45.323] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-14-mos-1-ols-2-bs-1-output with runnerParams (instances=1)
# [2023-08-14 01:11:45.591] [info] Model at path model_configurator_output/compiled_models/qpc-cores-14-mos-1-ols-2-bs-1-output with runnerParams (instances=1) running on device ID 0
# [2023-08-14 01:11:50.630] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-14-mos-1-ols-1-bs-2-output with runnerParams (instances=1)
# [2023-08-14 01:11:50.933] [info] Model at path model_configurator_output/compiled_models/qpc-cores-14-mos-1-ols-1-bs-2-output with runnerParams (instances=1) running on device ID 0
# [2023-08-14 01:11:55.978] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-14-mos-2-ols-1-bs-1-output with runnerParams (instances=1)
# [2023-08-14 01:11:56.237] [info] Model at path model_configurator_output/compiled_models/qpc-cores-14-mos-2-ols-1-bs-1-output with runnerParams (instances=1) running on device ID 0
# [2023-08-14 01:12:01.281] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-14-mos-1-ols-2-bs-1-output with runnerParams (instances=1)
# [2023-08-14 01:12:01.541] [info] Model at path model_configurator_output/compiled_models/qpc-cores-14-mos-1-ols-2-bs-1-output with runnerParams (instances=1) running on device ID 0
# [2023-08-14 01:12:06.581] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-14-mos-1-ols-1-bs-2-output with runnerParams (instances=1)
# [2023-08-14 01:12:06.883] [info] Model at path model_configurator_output/compiled_models/qpc-cores-14-mos-1-ols-1-bs-2-output with runnerParams (instances=1) running on device ID 0
# [2023-08-14 01:12:11.928] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-14-mos-2-ols-1-bs-1-output with runnerParams (instances=1)
# [2023-08-14 01:12:12.185] [info] Model at path model_configurator_output/compiled_models/qpc-cores-14-mos-2-ols-1-bs-1-output with runnerParams (instances=1) running on device ID 0
# [2023-08-14 01:12:17.227] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-14-mos-1-ols-2-bs-1-output with runnerParams (instances=1)
# [2023-08-14 01:12:17.490] [info] Model at path model_configurator_output/compiled_models/qpc-cores-14-mos-1-ols-2-bs-1-output with runnerParams (instances=1) running on device ID 0
# [2023-08-14 01:12:22.525] [info] Running model at path model_configurator_output/compiled_models/qpc-cores-14-mos-1-ols-1-bs-2-output with runnerParams (instances=1)
# [2023-08-14 01:12:22.828] [info] Model at path model_configurator_output/compiled_models/qpc-cores-14-mos-1-ols-1-bs-2-output with runnerParams (instances=1) running on device ID 0
# 2023-08-14 01:12:28.149 - [INFO]: Optimized search results:
#    OptimizerStatus                        InitialValue                      cores mos   ols  batchSize  instances  Objective (micro-sec)
# 0            SUCCESS   (cores=1, mos=[1], ols=1, batchSize=1, instances=1)   11    [1]   1       1          1             780.10
# 1  NUMERICAL_FAILURE   (cores=2, mos=[1], ols=1, batchSize=1, instances=1)   12    [8]   1       1          1             979.98
# 2  NUMERICAL_FAILURE   (cores=4, mos=[1], ols=1, batchSize=1, instances=1)   13    [2]   1       1          1             875.94
# 3            SUCCESS   (cores=7, mos=[1], ols=1, batchSize=1, instances=1)    7    [1]   1       1          1             827.65
# 4            SUCCESS  (cores=14, mos=[1], ols=1, batchSize=1, instances=1)    7    [1]   1       1          1             827.65
# 2023-08-14 01:12:28.150 - [INFO]: Total execution time 00:44:10.468

# %% [markdown]
# The Configuration with 9 cores and batch size 1 is returned as the configuration that provides least latency per image. Developers could also use row 3 which uses 7 cores. On a device with 14 cores, users can run 2 instances with a slight increase in latency.(Configurations depend on the card variant that the test is being run on)

# %%
## aic-num-cores =7 and instances = 1
# !rm -rf compiled_fp16
# !rm -rf resnet50_stats
# !mkdir resnet50_stats

# !/opt/qti-aic/exec/qaic-exec -v -aic-hw  \
-m=resnet-50_onnx/model.onnx \
-onnx-define-symbol=batch_size,1 \
-onnx-define-symbol=num_channels,3 -onnx-define-symbol=height,224  -onnx-define-symbol=width,224 \
-mos=1 -ols=1 -aic-num-cores=7 \
-stats-batchsize=1 -aic-binary-dir=./compiled_fp16 \
-multicast-weights -convert-to-fp16 \
-aic-hw-version=2.0 -compile-only
# Out:
# Reading ONNX Model from resnet-50_onnx/model.onnx
# Compile started ...............
# Compiling model with FP16 precision.
# WARNING: /resnet/encoder/stages.0/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_503/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.0/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_524/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_584/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.2/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_593/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.0/layer/layer.1/convolution/Conv/_onnx::Conv_629/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.1/layer/layer.1/convolution/Conv/_onnx::Conv_641/ contains value or values that will underflow after conversion to 16-bit floating point values.
# WARNING: /resnet/encoder/stages.3/layers.2/layer/layer.1/convolution/Conv/_onnx::Conv_650/ contains value or values that will underflow after conversion to 16-bit floating point values.
# Generated binary is present at ./compiled_fp16

# %%
# Running a single instance of the compiled binary
# !/opt/qti-aic/exec/qaic-runner --test-data ./compiled_fp16  -d 0 -a 1 -S 1\
--aic-profiling-type latency --aic-profiling-out-dir ./resnet50_stats \
--aic-profiling-start-iter 100 --aic-profiling-num-samples 99999 --time 10
# Out:
# Using bounded random inputs
#  ---- Stats ----
# InferenceCnt 6794 TotalDuration 10001122us BatchSize 1 Inf/Sec 679.324
# Writing file:./resnet50_stats/aic-profiling-program-1-latency.txt

# %%
# Measure latency for the single instance
# !python3 latency_stats_python3.py ./resnet50_stats/aic-profiling-program-1-latency.txt
# Out:
# All activations combined:
#                         mean       min       50%       75%       90%       95%       99%       max
# hostRoundTrip       1.312575  1.231000  1.294000  1.327000  1.435000  1.446000  1.464000  1.492000
# enqTime             0.001728  0.000500  0.001640  0.001880  0.002095  0.002512  0.012450  0.025920
# preProcTime         0.039130  0.021760  0.038410  0.040120  0.049170  0.051342  0.054892  0.134740
# submitTime          0.001599  0.000730  0.001640  0.001720  0.001820  0.001910  0.002181  0.003480
# execTotal           1.349014  1.245429  1.330669  1.359973  1.472174  1.488212  1.508741  1.738829
# exectoVc            0.003822  0.002000  0.004000  0.004000  0.004000  0.005000  0.005000  0.018000
# execToComplete      1.308754  1.227000  1.290000  1.324000  1.431000  1.442000  1.460050  1.488000
# postProc            0.002622  0.001090  0.002730  0.002980  0.003390  0.003510  0.003681  0.008360
# totalRoundtripTime  1.428489  1.308220  1.409549  1.429133  1.562219  1.580727  1.603432  3.737069
# totalRoundtripTime: percentile(mean) = 1.428 ms

# %%
# Running 2 instances of the compiled binary
# !/opt/qti-aic/exec/qaic-runner --test-data ./compiled_fp16  -d 0 -a 2 -S 1\
--aic-profiling-type latency --aic-profiling-out-dir ./resnet50_stats \
--aic-profiling-start-iter 100 --aic-profiling-num-samples 99999 --time 10
# Out:
# Using bounded random inputs
#  ---- Stats ----
# InferenceCnt 13618 TotalDuration 10001401us BatchSize 1 Inf/Sec 1361.609
# Deleting previous file: ./resnet50_stats/aic-profiling-program-1-latency.txt
# Writing file:./resnet50_stats/aic-profiling-program-1-latency.txt
# Deleting previous file: ./resnet50_stats/aic-profiling-program-2-latency.txt
# Writing file:./resnet50_stats/aic-profiling-program-2-latency.txt

# %%
# Measure latency for 2 instances
# !python3 latency_stats_python3.py ./resnet50_stats/aic-profiling-program-1-latency.txt \
./resnet50_stats/aic-profiling-program-2-latency.txt
# Out:
# All activations combined:
#                         mean       min       50%       75%       90%       95%       99%        max
# hostRoundTrip       1.327107  1.230000  1.316000  1.367000  1.427300  1.443000  1.460000   1.657000
# enqTime             0.001580  0.000380  0.001130  0.001840  0.002180  0.002553  0.011415   0.030310
# preProcTime         0.041181  0.020850  0.040440  0.047270  0.049940  0.050830  0.056898   0.240070
# submitTime          0.001539  0.000690  0.001610  0.001850  0.001940  0.001990  0.002200   0.178449
# execTotal           1.360584  1.248899  1.342910  1.382374  1.468207  1.488359  1.507152  21.086203
# exectoVc            0.003826  0.002000  0.004000  0.004000  0.005000  0.005000  0.005000   0.195000
# execToComplete      1.323280  1.227000  1.312000  1.364000  1.423000  1.439000  1.456000   1.654000
# postProc            0.002417  0.000970  0.002610  0.003070  0.003340  0.003460  0.003650   0.014200
# totalRoundtripTime  1.434842  1.303159  1.418999  1.434157  1.563867  1.585086  1.605804  21.170333
# totalRoundtripTime: percentile(mean) = 1.435 ms

# %% [markdown]
# We see that the throughput has increased significantly (~680 -> ~1360 inf/s) while latency has also increased but only slightly (~~1.428ms to ~1.435ms).
